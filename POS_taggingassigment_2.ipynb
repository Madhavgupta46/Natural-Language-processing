# %% [markdown]
# # **Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy). Analyze the grammatical structure of sentences using syntactic/dependency parsing.**

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = """
Bitcoin (abbreviation: BTC; sign: ₿) is the first decentralized cryptocurrency. Based on a free-market ideology, bitcoin was invented in 2008 when an unknown entity published a white paper under the pseudonym of Satoshi Nakamoto.[4] Use of bitcoin as a currency began in 2009,[5] with the release of its open-source implementation.[6]: ch. 1  From 2021 to 2025, El Salvador adopted it as legal tender currency before revoking it.[7][8][9] As bitcoin is pseudonymous, its use by criminals has attracted the attention of regulators, leading to its ban by several countries.[10]

Bitcoin works through the collaboration of computers, each of which acts as a node in the peer-to-peer bitcoin network. Each node maintains an independent copy of a public distributed ledger of transactions, called a blockchain, without central oversight. Transactions are validated through the use of cryptography, preventing one person from spending another person's bitcoin, as long as the owner of the bitcoin keeps certain sensitive data secret.[6]: ch. 5

Consensus between nodes about the content of the blockchain is achieved using a computationally intensive process based on proof of work, called mining, which is performed by purpose-built computers.[6]: ch. 12  Mining consumes large quantities of electricity and has been criticized for its environmental impact.[11]

History
Main article: History of bitcoin
Background
Before bitcoin, several digital cash technologies were released, starting with David Chaum's ecash in the 1980s.[12] The idea that solutions to computational puzzles could have some value was first proposed by cryptographers Cynthia Dwork and Moni Naor in 1992.[13][12] The concept was independently rediscovered by Adam Back who developed Hashcash, a proof-of-work scheme for spam control in 1997.[12] The first proposals for distributed digital scarcity-based cryptocurrencies came from cypherpunks Wei Dai (b-money) and Nick Szabo (bit gold) in 1998.[14] In 2004, Hal Finney developed the first currency based on reusable proof of work.[15] These various attempts were not successful:[12] Chaum's concept required centralized control and no banks wanted to sign on, Hashcash had no protection against double-spending, while b-money and bit gold were not resistant to Sybil attacks.[12]

2008–2009: Creation
External image
image icon Cover page of The Times 3 January 2009 showing the headline used in the genesis block


Bitcoin logos made by Satoshi Nakamoto in 2009 (left) and 2010 (right).
The domain name bitcoin.org was registered on 18 August 2008.[16] On 31 October 2008, a link to a white paper authored by Satoshi Nakamoto titled Bitcoin: A Peer-to-Peer Electronic Cash System was posted to a cryptography mailing list.[17] Nakamoto's identity remains unknown.[4] According to computer scientist Arvind Narayanan, all individual components of bitcoin originated in earlier academic literature.[12] Nakamoto's innovation was their complex interplay resulting in the first decentralized, Sybil resistant, Byzantine fault tolerant digital cash system, that would eventually be referred to as the first blockchain.[12][18] Nakamoto's paper was not peer reviewed and was initially ignored by academics, who argued that it could not work.[12]

Nakamoto released bitcoin as open-source software.[19] On 3 January 2009, the bitcoin network was created when Nakamoto mined the starting block of the chain, known as the genesis block.[20] Embedded in this block was the text "The Times 03/Jan/2009 Chancellor on brink of second bailout for banks", which is the date and headline of an issue of The Times newspaper.[5] Nine days later, Hal Finney received the first bitcoin transaction: ten bitcoins from Nakamoto.[21] Wei Dai and Nick Szabo were also early supporters.[20] On May 22, 2010, the first known commercial transaction using bitcoin occurred when programmer Laszlo Hanyecz bought two Papa John's pizzas for ₿10,000, in what would later be celebrated as "Bitcoin Pizza Day".[22] Satoshi tasked Finnish developer and early Bitcoin contributor Martti Malmi (fi) with creating content for the bitcoin.org website.[23][24]

2010–2012: Early growth
Blockchain analysts estimate that Nakamoto had mined about one million bitcoins[25] before disappearing in 2010 when he handed the network alert key and control of the code repository over to Gavin Andresen. Andresen later became lead developer at the Bitcoin Foundation,[26][27] an organization founded in September 2012 to promote bitcoin.[28]

After early "proof-of-concept" transactions, the first major users of bitcoin were black markets, such as the dark web Silk Road. During its 30 months of existence, beginning in February 2011, Silk Road exclusively accepted bitcoins as payment, transacting ₿9.9 million, worth about $214 million.[29]: 222

2013–2014: First regulatory actions
In March 2013, the US Financial Crimes Enforcement Network (FinCEN) established regulatory guidelines for "decentralized virtual currencies" such as bitcoin, classifying American bitcoin miners who sell their generated bitcoins as money services businesses, subject to registration and other legal obligations.[30] In May 2013, US authorities seized the unregistered exchange Mt. Gox.[31] In June 2013, the US Drug Enforcement Administration seized ₿11.02 from an individual attempting to use them to purchase illicit drugs. This marked the first time a government agency had seized bitcoins.[32] The FBI seized about ₿30,000 in October 2013 from Silk Road, following the arrest of its founder Ross Ulbricht.[33]

In December 2013, the People's Bank of China prohibited Chinese financial institutions from using bitcoin.[34] After the announcement, the value of bitcoin dropped,[35] and Baidu no longer accepted bitcoins for certain services.[36] Buying real-world goods with any virtual currency had been illegal in China since at least 2009.[37]

2015–2019
Research produced by the University of Cambridge estimated that in 2017, there were 2.9 to 5.8 million unique users using a cryptocurrency wallet, most of them using bitcoin.[38] In August 2017, the SegWit software upgrade was activated. Segwit was intended to support the Lightning Network as well as improve scalability.[39] SegWit opponents, who supported larger blocks as a scalability solution, forked to create Bitcoin Cash, one of many forks of bitcoin.[40]

In December 2017, the first futures on bitcoin was introduced by the Chicago Mercantile Exchange (CME).[41]

In February 2018, the price crashed after China imposed a complete ban on bitcoin trading.[42] The percentage of bitcoin trading in the Chinese renminbi fell from over 90% in September 2017 to less than 1% in June 2018.[43] During the same year, bitcoin prices were negatively affected by several hacks or thefts from cryptocurrency exchanges.[44]

2020–present

Bitcoin price[45]
December 1, 2014 –
December 4, 2024
In 2020, some major companies and institutions started to acquire bitcoin: MicroStrategy invested $250 million in bitcoin as a treasury reserve asset,[46] Square, Inc., $50 million,[47] and MassMutual, $100 million.[48] In November 2020, PayPal added support for bitcoin in the US.[49]

In February 2021, bitcoin's market capitalization reached $1 trillion for the first time.[50] In November 2021, the Taproot soft-fork upgrade was activated, adding support for Schnorr signatures, improved functionality of smart contracts and Lightning Network.[51] Before, bitcoin only used a custom elliptic curve with the ECDSA algorithm to produce signatures.[52]: 101  In September 2021, bitcoin became legal tender currency in El Salvador, alongside the US dollar.[7] In October 2021, the first bitcoin futures exchange-traded fund (ETF), called BITO, from ProShares was approved by the SEC and listed on the CME.[53]

In early 2022, during the Canadian trucker protests opposing COVID-19 vaccine mandates, organizers turned to bitcoin to receive donations after traditional financial platforms restricted access to funding.[54][55] Proponents highlighted bitcoin's use as a tool for fundraising in situations where access to conventional financial systems may be restricted.[56][57] In May and June 2022, the bitcoin price fell following the collapses of TerraUSD, a stablecoin,[58] and the Celsius Network, a cryptocurrency loan company.[59][60]

In 2023, ordinals—non-fungible tokens (NFTs)—on bitcoin, went live.[61] As of June 2023, River Financial estimated that bitcoin had 81.7 million users, about 1% of the global population.[62]

In January 2024, the first 11 US spot bitcoin ETFs began trading, offering direct exposure to bitcoin for the first time on American stock exchanges.[63][64] In December 2024, bitcoin price reached $100,000 for the first time, as US president-elect Donald Trump promised to make the US the "crypto capital of the planet" and to stockpile bitcoin.[65] The same month, BlackRock, the world's largest asset manager, recommended investors to allocate up to 2% of their portfolio to bitcoin.[66]

As of 2025, the Salvadoran government continues to describe Bitcoin as legal tender under the 2021 Bitcoin Law; however, a January 2025 reform removed obligations for businesses and the government to accept it, so many analysts regard its legal-tender status as effectively ended in practice.[8][9] In March 2025, President Trump signed an executive order to establish a strategic bitcoin reserve.[67] Later that year, some U.S. states, such as Texas and New Hampshire also instituted strategic bitcoin reserves,[68] and the Czech National Bank bought less than €1 million in a "test portfolio".[69]

Design
Main article: Bitcoin protocol
Units and divisibility
The unit of account of the bitcoin system is the bitcoin. It is most commonly represented with the symbol ₿[1] and the currency code BTC. However, the BTC code does not conform to ISO 4217 as BT is the country code of Bhutan,[70] and ISO 4217 requires the first letter used in global commodities to be 'X'.[70] XBT, a code that conforms to ISO 4217 though not officially part of it,[70] is used by Bloomberg L.P.[71]

No uniform capitalization convention exists; some sources use Bitcoin, capitalized, to refer to the technology and network, and bitcoin, lowercase, for the unit of account.[72] The Cambridge Advanced Learner's Dictionary and the Oxford Advanced Learner's Dictionary use the capitalized and lowercase variants without distinction.[73][74]

One bitcoin is divisible to eight decimal places.[6]: ch. 5  Units for smaller amounts of bitcoin are the millibitcoin (mBTC), equal to 1⁄1000 bitcoin, and the satoshi[a] (sat), representing 1⁄100000000 (one hundred millionth) bitcoin, the smallest amount possible.[2] 100,000 satoshis are one mBTC.[75]

Blockchain
Further information: Blockchain § Structure and design
As a decentralized system, bitcoin operates without a central authority or single administrator,[76] so that anyone can create a new bitcoin address and transact without needing any approval.[6]: ch. 1  This is accomplished through a specialized distributed ledger called a blockchain that records bitcoin transactions.[77]

The blockchain is implemented as an ordered list of blocks. Each block contains a SHA-256 hash of the previous block,[77] chaining them in chronological order.[6]: ch. 7 [77] The blockchain is maintained by a peer-to-peer network.[29]: 215–219  Individual blocks, public addresses, and transactions within blocks are public information, and can be examined using a blockchain explorer.[78]

Nodes validate and broadcast transactions, each maintaining a copy of the blockchain for ownership verification.[79] A new block is created every 10 minutes on average, updating the blockchain across all nodes without central oversight. This process tracks bitcoin spending, ensuring each bitcoin is spent only once. Unlike a traditional ledger that tracks physical currency, bitcoins exist digitally as unspent outputs of transactions.[6]: ch. 5

Addresses and transactions

Simplified chain of ownership. In practice, a transaction can have more than one input and more than one output.[80]
In the blockchain, bitcoins are linked to specific strings called addresses. Most often, an address encodes a hash of a single public key. Creating such an address involves generating a random private key and then computing the corresponding address. This process is almost instant, but the reverse (finding the private key for a given address) is nearly impossible.[6]: ch. 4  Publishing such a bitcoin address does not risk its private key, and it is extremely unlikely to accidentally generate a used key with funds. To use bitcoins, owners need their private key to digitally sign transactions, which are verified by the network using the public key, keeping the private key secret.[6]: ch. 5  An address may encode the hash of a bitcoin script that specifies more complex requirements to spend the funds. One common example is "multisig", in which multiple distinct private keys must mutually sign any transaction that attempts to spend the funds.[6]: ch. 7

Bitcoin transactions use a Forth-like scripting language,[6]: ch. 5  involving one or more inputs and outputs. When sending bitcoins, a user specifies the recipients' addresses and the amount for each output. This allows sending bitcoins to several recipients in a single transaction. To prevent double-spending, each input must refer to a previous unspent output in the blockchain.[80] Using multiple inputs is similar to using multiple coins in a cash transaction. As in a cash transaction, the sum of inputs can exceed the intended sum of payments. In such a case, an additional output can return the change back to the payer.[80] Unallocated input satoshis in the transaction become the transaction fee.[80]

Losing a private key means losing access to the bitcoins, with no other proof of ownership accepted by the protocol.[29] For instance, in 2013, a user lost ₿7,500, valued at US$7.5 million, by accidentally discarding a hard drive with the private key.[81] It is estimated that around 20% of all bitcoins are lost.[82] The private key must also be kept secret as its exposure, such as through a data breach, can lead to theft of the associated bitcoins.[6]: ch. 10 [83] As of December 2017, approximately ₿980,000 had been stolen from cryptocurrency exchanges.[84]
"""

# %%
doc=nlp(text)

# %% [markdown]
# #POS tagging

# %%
for token in doc:
    print(f"{token.text:15}  POS: {token.pos_:10}  TAG: {token.tag_:10}  DEP: {token.dep_}  Description: {spacy.explain(token.tag_)}")
# Out:
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Bitcoin          POS: PROPN       TAG: NNP         DEP: dep  Description: noun, proper singular
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# abbreviation     POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# BTC              POS: NOUN        TAG: NNS         DEP: appos  Description: noun, plural
# ;                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# sign             POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# ₿                POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# first            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# decentralized    POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# cryptocurrency   POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Based            POS: VERB        TAG: VBN         DEP: prep  Description: verb, past participle
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# free             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# market           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# ideology         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# bitcoin          POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# was              POS: AUX         TAG: VBD         DEP: auxpass  Description: verb, past tense
# invented         POS: VERB        TAG: VBN         DEP: ccomp  Description: verb, past participle
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 2008             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# when             POS: SCONJ       TAG: WRB         DEP: advmod  Description: wh-adverb
# an               POS: DET         TAG: DT          DEP: det  Description: determiner
# unknown          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# entity           POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# published        POS: VERB        TAG: VBD         DEP: advcl  Description: verb, past tense
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# white            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# paper            POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# under            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# pseudonym        POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Satoshi          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Nakamoto.[4      POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# Use              POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# bitcoin          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# currency         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# began            POS: VERB        TAG: VBD         DEP: conj  Description: verb, past tense
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 2009,[5          POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# release          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# open             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# source           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# implementation.[6  POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
#                  POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# ch               POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# .                POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 1                POS: NUM         TAG: CD          DEP: punct  Description: cardinal number
#                  POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# From             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 2021             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 2025             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# El               POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Salvador         POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# adopted          POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# it               POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# legal            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# tender           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# currency         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# before           POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# revoking         POS: VERB        TAG: VBG         DEP: pcomp  Description: verb, gerund or present participle
# it.[7][8][9      POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# As               POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# bitcoin          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: advcl  Description: verb, 3rd person singular present
# pseudonymous     POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# use              POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# by               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# criminals        POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# has              POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
# attracted        POS: VERB        TAG: VBN         DEP: conj  Description: verb, past participle
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# attention        POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# regulators       POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# leading          POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# ban              POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# several          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# countries.[10    POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Bitcoin          POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# works            POS: VERB        TAG: VBZ         DEP: ccomp  Description: verb, 3rd person singular present
# through          POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# collaboration    POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# computers        POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# each             POS: PRON        TAG: DT          DEP: nsubj  Description: determiner
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# which            POS: PRON        TAG: WDT         DEP: pobj  Description: wh-determiner
# acts             POS: VERB        TAG: VBZ         DEP: relcl  Description: verb, 3rd person singular present
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# node             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# peer             POS: NOUN        TAG: NN          DEP: nmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# peer             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# bitcoin          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# network          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Each             POS: DET         TAG: DT          DEP: det  Description: determiner
# node             POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# maintains        POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# an               POS: DET         TAG: DT          DEP: det  Description: determiner
# independent      POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# copy             POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# public           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# distributed      POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# ledger           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# transactions     POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# called           POS: VERB        TAG: VBD         DEP: conj  Description: verb, past tense
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# blockchain       POS: NOUN        TAG: NN          DEP: oprd  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# without          POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# central          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# oversight        POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Transactions     POS: NOUN        TAG: NNS         DEP: nsubjpass  Description: noun, plural
# are              POS: AUX         TAG: VBP         DEP: auxpass  Description: verb, non-3rd person singular present
# validated        POS: VERB        TAG: VBN         DEP: ccomp  Description: verb, past participle
# through          POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# use              POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# cryptography     POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# preventing       POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# one              POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# person           POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# spending         POS: VERB        TAG: VBG         DEP: pcomp  Description: verb, gerund or present participle
# another          POS: DET         TAG: DT          DEP: det  Description: determiner
# person           POS: NOUN        TAG: NN          DEP: poss  Description: noun, singular or mass
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# bitcoin          POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# as               POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# long             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# as               POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# owner            POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# bitcoin          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# keeps            POS: VERB        TAG: VBZ         DEP: advcl  Description: verb, 3rd person singular present
# certain          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# sensitive        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# data             POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# secret.[6        POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
#                  POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# ch               POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# .                POS: PROPN       TAG: NNP         DEP: nsubjpass  Description: noun, proper singular
# 5                POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
#
#
#               POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Consensus        POS: PROPN       TAG: NNP         DEP: nsubjpass  Description: noun, proper singular
# between          POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# nodes            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# about            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# content          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# blockchain       POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: auxpass  Description: verb, 3rd person singular present
# achieved         POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# using            POS: VERB        TAG: VBG         DEP: xcomp  Description: verb, gerund or present participle
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# computationally  POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# intensive        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# process          POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# based            POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# proof            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# work             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# called           POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# mining           POS: NOUN        TAG: NN          DEP: oprd  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# which            POS: PRON        TAG: WDT         DEP: nsubjpass  Description: wh-determiner
# is               POS: AUX         TAG: VBZ         DEP: auxpass  Description: verb, 3rd person singular present
# performed        POS: VERB        TAG: VBN         DEP: relcl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# purpose          POS: NOUN        TAG: NN          DEP: npadvmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# built            POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# computers.[6     POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
#                  POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# ch               POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# .                POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 12               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
#                  POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Mining           POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# consumes         POS: VERB        TAG: VBZ         DEP: conj  Description: verb, 3rd person singular present
# large            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# quantities       POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# electricity      POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# has              POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
# been             POS: AUX         TAG: VBN         DEP: auxpass  Description: verb, past participle
# criticized       POS: VERB        TAG: VBN         DEP: conj  Description: verb, past participle
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# environmental    POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# impact.[11       POS: NOUN        TAG: NN          DEP: nmod  Description: noun, singular or mass
# ]                POS: PUNCT       TAG: -RRB-       DEP: dep  Description: right round bracket
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# History          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Main             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# article          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# History          POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# bitcoin          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Background       POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Before           POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# bitcoin          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# several          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# digital          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# cash             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# technologies     POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# were             POS: AUX         TAG: VBD         DEP: auxpass  Description: verb, past tense
# released         POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# starting         POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# David            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Chaum            POS: PROPN       TAG: NNP         DEP: poss  Description: noun, proper singular
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# ecash            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# 1980s.[12        POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# idea             POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# that             POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# solutions        POS: NOUN        TAG: NNS         DEP: nsubj  Description: noun, plural
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# computational    POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# puzzles          POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# could            POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# have             POS: AUX         TAG: VB          DEP: acl  Description: verb, base form
# some             POS: DET         TAG: DT          DEP: det  Description: determiner
# value            POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# was              POS: AUX         TAG: VBD         DEP: auxpass  Description: verb, past tense
# first            POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# proposed         POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# cryptographers   POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# Cynthia          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Dwork            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Moni             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Naor             POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1992.[13][12     POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# concept          POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# was              POS: AUX         TAG: VBD         DEP: auxpass  Description: verb, past tense
# independently    POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# rediscovered     POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# Adam             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Back             POS: ADV         TAG: RB          DEP: pobj  Description: adverb
# who              POS: PRON        TAG: WP          DEP: nsubj  Description: wh-pronoun, personal
# developed        POS: VERB        TAG: VBD         DEP: relcl  Description: verb, past tense
# Hashcash         POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# proof            POS: NOUN        TAG: NN          DEP: nmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# work             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# scheme           POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# spam             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# control          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1997.[12         POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# first            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# proposals        POS: NOUN        TAG: NNS         DEP: nsubj  Description: noun, plural
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# distributed      POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# digital          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# scarcity         POS: NOUN        TAG: NN          DEP: npadvmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# based            POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# cryptocurrencies  POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# came             POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# cypherpunks      POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# Wei              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Dai              POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# b                POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# money            POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Nick             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Szabo            POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# bit              POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# gold             POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1998.[14         POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# In               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 2004             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Hal              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Finney           POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# developed        POS: VERB        TAG: VBD         DEP: ccomp  Description: verb, past tense
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# first            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# currency         POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# based            POS: VERB        TAG: VBN         DEP: prep  Description: verb, past participle
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# reusable         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# proof            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# work.[15         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# These            POS: DET         TAG: DT          DEP: det  Description: determiner
# various          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# attempts         POS: NOUN        TAG: NNS         DEP: nsubj  Description: noun, plural
# were             POS: AUX         TAG: VBD         DEP: ccomp  Description: verb, past tense
# not              POS: PART        TAG: RB          DEP: neg  Description: adverb
# successful:[12   POS: X           TAG: FW          DEP: acomp  Description: foreign word
# ]                POS: X           TAG: XX          DEP: dep  Description: unknown
# Chaum            POS: PROPN       TAG: NNP         DEP: poss  Description: noun, proper singular
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# concept          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# required         POS: VERB        TAG: VBD         DEP: conj  Description: verb, past tense
# centralized      POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# control          POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# no               POS: DET         TAG: DT          DEP: det  Description: determiner
# banks            POS: NOUN        TAG: NNS         DEP: nsubj  Description: noun, plural
# wanted           POS: VERB        TAG: VBD         DEP: conj  Description: verb, past tense
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# sign             POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# on               POS: ADP         TAG: RP          DEP: prt  Description: adverb, particle
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Hashcash         POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# had              POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# no               POS: DET         TAG: DT          DEP: det  Description: determiner
# protection       POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# against          POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# double           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# spending         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# while            POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# b                POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# money            POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# bit              POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# gold             POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# were             POS: AUX         TAG: VBD         DEP: advcl  Description: verb, past tense
# not              POS: PART        TAG: RB          DEP: neg  Description: adverb
# resistant        POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Sybil            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# attacks.[12      POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ]                POS: X           TAG: XX          DEP: punct  Description: unknown
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 2008–2009        POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# Creation         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# External         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# image            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# image            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# icon             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# Cover            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# page             POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# Times            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 3                POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# January          POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 2009             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# showing          POS: VERB        TAG: VBG         DEP: acl  Description: verb, gerund or present participle
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# headline         POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# used             POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# genesis          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# block            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
#
#
#
#               POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Bitcoin          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# logos            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# made             POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# Satoshi          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Nakamoto         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 2009             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# left             POS: ADV         TAG: RB          DEP: parataxis  Description: adverb
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# 2010             POS: NUM         TAG: CD          DEP: conj  Description: cardinal number
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# right            POS: INTJ        TAG: UH          DEP: parataxis  Description: interjection
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# domain           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# name             POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# bitcoin.org      POS: X           TAG: ADD         DEP: appos  Description: email
# was              POS: AUX         TAG: VBD         DEP: auxpass  Description: verb, past tense
# registered       POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# ...
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# sum              POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# inputs           POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# exceed           POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# intended         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# sum              POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# payments         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# In               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# such             POS: DET         TAG: PDT         DEP: predet  Description: predeterminer
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# case             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# an               POS: DET         TAG: DT          DEP: det  Description: determiner
# additional       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# output           POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# return           POS: VERB        TAG: VB          DEP: ccomp  Description: verb, base form
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# change           POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# back             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# payer.[80        POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# Unallocated      POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# input            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# satoshis         POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# transaction      POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# become           POS: VERB        TAG: VBP         DEP: ccomp  Description: verb, non-3rd person singular present
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# transaction      POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# fee.[80          POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Losing           POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# private          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# key              POS: NOUN        TAG: NN          DEP: amod  Description: noun, singular or mass
# means            POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# losing           POS: VERB        TAG: VBG         DEP: acl  Description: verb, gerund or present participle
# access           POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# bitcoins         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# no               POS: DET         TAG: DT          DEP: det  Description: determiner
# other            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# proof            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# ownership        POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# accepted         POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# protocol.[29     POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ]                POS: X           TAG: XX          DEP: dobj  Description: unknown
# For              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# instance         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 2013             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# user             POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# lost             POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# ₿                POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# 7,500            POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# valued           POS: VERB        TAG: VBN         DEP: advcl  Description: verb, past participle
# at               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# US$              POS: SYM         TAG: $           DEP: quantmod  Description: symbol, currency
# 7.5              POS: NUM         TAG: CD          DEP: compound  Description: cardinal number
# million          POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# by               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# accidentally     POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# discarding       POS: VERB        TAG: VBG         DEP: pcomp  Description: verb, gerund or present participle
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# hard             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# drive            POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# private          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# key.[81          POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ]                POS: X           TAG: XX          DEP: punct  Description: unknown
# It               POS: PRON        TAG: PRP         DEP: nsubjpass  Description: pronoun, personal
# is               POS: AUX         TAG: VBZ         DEP: auxpass  Description: verb, 3rd person singular present
# estimated        POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# that             POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# around           POS: ADP         TAG: IN          DEP: advmod  Description: conjunction, subordinating or preposition
# 20               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# %                POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# all              POS: DET         TAG: DT          DEP: det  Description: determiner
# bitcoins         POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# are              POS: AUX         TAG: VBP         DEP: ccomp  Description: verb, non-3rd person singular present
# lost.[82         POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# ]                POS: X           TAG: XX          DEP: punct  Description: unknown
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# private          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# key              POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# must             POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# also             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# be               POS: AUX         TAG: VB          DEP: auxpass  Description: verb, base form
# kept             POS: VERB        TAG: VBN         DEP: conj  Description: verb, past participle
# secret           POS: ADJ         TAG: JJ          DEP: oprd  Description: adjective (English), other noun-modifier (Chinese)
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# exposure         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# such             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# through          POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# data             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# breach           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# lead             POS: VERB        TAG: VB          DEP: ccomp  Description: verb, base form
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# theft            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# associated       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# bitcoins.[6      POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
#                  POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# ch               POS: NOUN        TAG: NN          DEP: npadvmod  Description: noun, singular or mass
# .                POS: PROPN       TAG: NNP         DEP: punct  Description: noun, proper singular
# 10               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
#                  POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# [                POS: X           TAG: XX          DEP: dep  Description: unknown
# 83               POS: NUM         TAG: CD          DEP: punct  Description: cardinal number
# ]                POS: PUNCT       TAG: -RRB-       DEP: dep  Description: right round bracket
# As               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# December         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 2017             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# approximately    POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# ₿                POS: PROPN       TAG: NNP         DEP: nsubjpass  Description: noun, proper singular
# 980,000          POS: NUM         TAG: CD          DEP: nsubjpass  Description: cardinal number
# had              POS: AUX         TAG: VBD         DEP: aux  Description: verb, past tense
# been             POS: AUX         TAG: VBN         DEP: auxpass  Description: verb, past participle
# stolen           POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# cryptocurrency   POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# exchanges.[84    POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ]                POS: X           TAG: ADD         DEP: pobj  Description: email
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace

# %% [markdown]
# #Dependency Parsing

# %%
for token in doc:
    print(f"{token.text:12} <--{token.dep_:10}-- {token.head.text}")
# Out:
#             <--dep       -- Bitcoin
# Bitcoin      <--dep       -- sign
# (            <--punct     -- Bitcoin
# abbreviation <--appos     -- Bitcoin
# :            <--punct     -- abbreviation
# BTC          <--appos     -- abbreviation
# ;            <--punct     -- sign
# sign         <--nsubj     -- is
# :            <--punct     -- sign
# ₿            <--npadvmod  -- sign
# )            <--punct     -- sign
# is           <--ROOT      -- is
# the          <--det       -- cryptocurrency
# first        <--amod      -- cryptocurrency
# decentralized <--amod      -- cryptocurrency
# cryptocurrency <--attr      -- is
# .            <--punct     -- is
# Based        <--prep      -- invented
# on           <--prep      -- Based
# a            <--det       -- ideology
# free         <--amod      -- market
# -            <--punct     -- market
# market       <--compound  -- ideology
# ideology     <--pobj      -- on
# ,            <--punct     -- invented
# bitcoin      <--nsubjpass -- invented
# was          <--auxpass   -- invented
# invented     <--ccomp     -- adopted
# in           <--prep      -- invented
# 2008         <--pobj      -- in
# when         <--advmod    -- published
# an           <--det       -- entity
# unknown      <--amod      -- entity
# entity       <--nsubj     -- published
# published    <--advcl     -- invented
# a            <--det       -- paper
# white        <--amod      -- paper
# paper        <--dobj      -- published
# under        <--prep      -- published
# the          <--det       -- pseudonym
# pseudonym    <--pobj      -- under
# of           <--prep      -- pseudonym
# Satoshi      <--compound  -- Nakamoto.[4
# Nakamoto.[4  <--nmod      -- Use
# ]            <--punct     -- Nakamoto.[4
# Use          <--pobj      -- of
# of           <--prep      -- Use
# bitcoin      <--pobj      -- of
# as           <--prep      -- Use
# a            <--det       -- currency
# currency     <--pobj      -- as
# began        <--conj      -- invented
# in           <--prep      -- began
# 2009,[5      <--pobj      -- in
# ]            <--punct     -- began
# with         <--prep      -- began
# the          <--det       -- release
# release      <--pobj      -- with
# of           <--prep      -- release
# its          <--poss      -- implementation.[6
# open         <--amod      -- source
# -            <--punct     -- source
# source       <--compound  -- implementation.[6
# implementation.[6 <--pobj      -- of
# ]            <--punct     -- release
# :            <--punct     -- ch
#              <--dep       -- :
# ch           <--appos     -- bitcoin
# .            <--npadvmod  -- invented
# 1            <--punct     -- invented
#              <--dep       -- 1
# From         <--prep      -- invented
# 2021         <--pobj      -- From
# to           <--prep      -- From
# 2025         <--pobj      -- to
# ,            <--punct     -- adopted
# El           <--compound  -- Salvador
# Salvador     <--nsubj     -- adopted
# adopted      <--ROOT      -- adopted
# it           <--dobj      -- adopted
# as           <--prep      -- adopted
# legal        <--amod      -- currency
# tender       <--compound  -- currency
# currency     <--pobj      -- as
# before       <--prep      -- adopted
# revoking     <--pcomp     -- before
# it.[7][8][9  <--dobj      -- revoking
# ]            <--punct     -- adopted
# As           <--mark      -- is
# bitcoin      <--nsubj     -- is
# is           <--advcl     -- attracted
# pseudonymous <--acomp     -- is
# ,            <--punct     -- attracted
# its          <--poss      -- use
# use          <--nsubj     -- attracted
# by           <--prep      -- use
# criminals    <--pobj      -- by
# has          <--aux       -- attracted
# attracted    <--conj      -- adopted
# the          <--det       -- attention
# attention    <--dobj      -- attracted
# of           <--prep      -- attention
# regulators   <--pobj      -- of
# ,            <--punct     -- attracted
# leading      <--advcl     -- attracted
# to           <--prep      -- leading
# its          <--poss      -- ban
# ban          <--pobj      -- to
# by           <--agent     -- leading
# several      <--amod      -- countries.[10
# countries.[10 <--nmod      -- Bitcoin
# ]            <--punct     -- Bitcoin
#
#
#            <--dep       -- ]
# Bitcoin      <--nsubj     -- works
# works        <--ccomp     -- leading
# through      <--prep      -- works
# the          <--det       -- collaboration
# collaboration <--pobj      -- through
# of           <--prep      -- collaboration
# computers    <--pobj      -- of
# ,            <--punct     -- collaboration
# each         <--nsubj     -- acts
# of           <--prep      -- each
# which        <--pobj      -- of
# acts         <--relcl     -- collaboration
# as           <--prep      -- acts
# a            <--det       -- node
# node         <--pobj      -- as
# in           <--prep      -- node
# the          <--det       -- network
# peer         <--nmod      -- network
# -            <--punct     -- peer
# to           <--prep      -- peer
# -            <--punct     -- to
# peer         <--pobj      -- to
# bitcoin      <--compound  -- network
# network      <--pobj      -- in
# .            <--punct     -- adopted
# Each         <--det       -- node
# node         <--nsubj     -- maintains
# maintains    <--ROOT      -- maintains
# an           <--det       -- copy
# independent  <--amod      -- copy
# copy         <--dobj      -- maintains
# of           <--prep      -- copy
# a            <--det       -- ledger
# public       <--amod      -- ledger
# distributed  <--amod      -- ledger
# ledger       <--pobj      -- of
# of           <--prep      -- ledger
# transactions <--pobj      -- of
# ,            <--punct     -- maintains
# called       <--conj      -- maintains
# a            <--det       -- blockchain
# blockchain   <--oprd      -- called
# ,            <--punct     -- called
# without      <--prep      -- called
# central      <--amod      -- oversight
# oversight    <--pobj      -- without
# .            <--punct     -- maintains
# Transactions <--nsubjpass -- validated
# are          <--auxpass   -- validated
# validated    <--ccomp     -- achieved
# through      <--prep      -- validated
# the          <--det       -- use
# use          <--pobj      -- through
# of           <--prep      -- use
# cryptography <--pobj      -- of
# ,            <--punct     -- validated
# preventing   <--advcl     -- validated
# one          <--nummod    -- person
# person       <--dobj      -- preventing
# from         <--prep      -- preventing
# spending     <--pcomp     -- from
# another      <--det       -- person
# person       <--poss      -- bitcoin
# 's           <--case      -- person
# bitcoin      <--dobj      -- spending
# ,            <--punct     -- validated
# as           <--advmod    -- long
# long         <--advmod    -- validated
# as           <--mark      -- keeps
# the          <--det       -- owner
# owner        <--nsubj     -- keeps
# of           <--prep      -- owner
# the          <--det       -- bitcoin
# bitcoin      <--pobj      -- of
# keeps        <--advcl     -- long
# certain      <--amod      -- secret.[6
# sensitive    <--amod      -- secret.[6
# data         <--compound  -- secret.[6
# secret.[6    <--dobj      -- keeps
# ]            <--punct     -- validated
# :            <--punct     -- validated
#              <--dep       -- :
# ch           <--nsubjpass -- achieved
# .            <--nsubjpass -- achieved
# 5            <--nummod    -- Consensus
#
#
#           <--dep       -- 5
# Consensus    <--nsubjpass -- achieved
# between      <--prep      -- Consensus
# nodes        <--pobj      -- between
# about        <--prep      -- nodes
# the          <--det       -- content
# content      <--pobj      -- about
# of           <--prep      -- content
# the          <--det       -- blockchain
# blockchain   <--pobj      -- of
# is           <--auxpass   -- achieved
# achieved     <--ROOT      -- achieved
# using        <--xcomp     -- achieved
# a            <--det       -- process
# computationally <--advmod    -- intensive
# intensive    <--amod      -- process
# process      <--dobj      -- using
# based        <--acl       -- process
# on           <--prep      -- based
# proof        <--pobj      -- on
# of           <--prep      -- proof
# work         <--pobj      -- of
# ,            <--punct     -- work
# called       <--acl       -- proof
# mining       <--oprd      -- called
# ,            <--punct     -- proof
# which        <--nsubjpass -- performed
# is           <--auxpass   -- performed
# performed    <--relcl     -- proof
# by           <--agent     -- performed
# purpose      <--npadvmod  -- built
# -            <--punct     -- built
# built        <--amod      -- computers.[6
# computers.[6 <--pobj      -- by
# ]            <--punct     -- achieved
# :            <--punct     -- achieved
#              <--dep       -- :
# ch           <--appos     -- ch
# .            <--npadvmod  -- achieved
# 12           <--nummod    -- Mining
#              <--dep       -- 12
# Mining       <--nsubj     -- consumes
# consumes     <--conj      -- achieved
# large        <--amod      -- quantities
# quantities   <--dobj      -- consumes
# of           <--prep      -- quantities
# electricity  <--pobj      -- of
# and          <--cc        -- consumes
# has          <--aux       -- criticized
# been         <--auxpass   -- criticized
# criticized   <--conj      -- consumes
# for          <--prep      -- criticized
# its          <--poss      -- article
# environmental <--amod      -- article
# impact.[11   <--nmod      -- article
# ]            <--dep       -- impact.[11
#
#
#            <--dep       -- ]
# History      <--compound  -- article
#
#             <--dep       -- History
# Main         <--amod      -- article
# article      <--pobj      -- for
# :            <--punct     -- article
# History      <--nsubjpass -- released
# of           <--prep      -- History
# bitcoin      <--compound  -- Background
#
#             <--dep       -- bitcoin
# Background   <--pobj      -- of
#
#             <--dep       -- Background
# Before       <--prep      -- History
# bitcoin      <--pobj      -- Before
# ,            <--punct     -- History
# several      <--amod      -- technologies
# digital      <--amod      -- technologies
# cash         <--compound  -- technologies
# technologies <--conj      -- History
# were         <--auxpass   -- released
# released     <--acl       -- article
# ,            <--punct     -- released
# starting     <--advcl     -- released
# with         <--prep      -- starting
# David        <--compound  -- Chaum
# Chaum        <--poss      -- ecash
# 's           <--case      -- Chaum
# ecash        <--pobj      -- with
# in           <--prep      -- starting
# the          <--det       -- 1980s.[12
# 1980s.[12    <--pobj      -- in
# ]            <--punct     -- article
# The          <--det       -- idea
# idea         <--nsubjpass -- proposed
# that         <--mark      -- have
# solutions    <--nsubj     -- have
# to           <--prep      -- solutions
# computational <--amod      -- puzzles
# puzzles      <--pobj      -- to
# could        <--aux       -- have
# have         <--acl       -- idea
# some         <--det       -- value
# value        <--dobj      -- have
# was          <--auxpass   -- proposed
# first        <--advmod    -- proposed
# proposed     <--ROOT      -- proposed
# by           <--agent     -- proposed
# cryptographers <--compound  -- Dwork
# Cynthia      <--compound  -- Dwork
# Dwork        <--pobj      -- by
# and          <--cc        -- Dwork
# Moni         <--compound  -- Naor
# Naor         <--conj      -- Dwork
# in           <--prep      -- proposed
# 1992.[13][12 <--pobj      -- in
# ]            <--punct     -- proposed
# The          <--det       -- concept
# concept      <--nsubjpass -- rediscovered
# was          <--auxpass   -- rediscovered
# independently <--advmod    -- rediscovered
# rediscovered <--ROOT      -- rediscovered
# by           <--agent     -- rediscovered
# Adam         <--compound  -- Back
# Back         <--pobj      -- by
# who          <--nsubj     -- developed
# developed    <--relcl     -- Back
# Hashcash     <--dobj      -- developed
# ,            <--punct     -- Hashcash
# a            <--det       -- scheme
# proof        <--nmod      -- scheme
# -            <--punct     -- proof
# of           <--prep      -- proof
# -            <--punct     -- of
# work         <--pobj      -- of
# scheme       <--appos     -- Hashcash
# for          <--prep      -- scheme
# spam         <--compound  -- control
# control      <--pobj      -- for
# in           <--prep      -- scheme
# 1997.[12     <--pobj      -- in
# ]            <--punct     -- rediscovered
# The          <--det       -- proposals
# first        <--amod      -- proposals
# proposals    <--nsubj     -- came
# for          <--prep      -- proposals
# distributed  <--amod      -- cryptocurrencies
# digital      <--amod      -- cryptocurrencies
# scarcity     <--npadvmod  -- based
# -            <--punct     -- based
# based        <--amod      -- cryptocurrencies
# cryptocurrencies <--pobj      -- for
# came         <--ROOT      -- came
# from         <--prep      -- came
# cypherpunks  <--compound  -- Dai
# Wei          <--compound  -- Dai
# Dai          <--pobj      -- from
# (            <--punct     -- Dai
# b            <--appos     -- Dai
# -            <--punct     -- b
# money        <--conj      -- b
# )            <--punct     -- Dai
# and          <--cc        -- Dai
# Nick         <--compound  -- Szabo
# Szabo        <--conj      -- Dai
# (            <--punct     -- gold
# bit          <--compound  -- gold
# gold         <--appos     -- Szabo
# )            <--punct     -- gold
# in           <--prep      -- came
# 1998.[14     <--pobj      -- in
# ]            <--punct     -- came
# In           <--prep      -- developed
# 2004         <--pobj      -- In
# ,            <--punct     -- developed
# Hal          <--compound  -- Finney
# Finney       <--nsubj     -- developed
# developed    <--ccomp     -- had
# the          <--det       -- currency
# first        <--amod      -- currency
# currency     <--dobj      -- developed
# based        <--prep      -- developed
# on           <--prep      -- based
# reusable     <--amod      -- proof
# proof        <--pobj      -- on
# of           <--prep      -- proof
# work.[15     <--pobj      -- of
# ]            <--punct     -- developed
# These        <--det       -- attempts
# various      <--amod      -- attempts
# attempts     <--nsubj     -- were
# were         <--ccomp     -- developed
# not          <--neg       -- were
# successful:[12 <--acomp     -- were
# ]            <--dep       -- were
# Chaum        <--poss      -- concept
# 's           <--case      -- Chaum
# concept      <--nsubj     -- required
# required     <--conj      -- developed
# centralized  <--amod      -- control
# control      <--dobj      -- required
# and          <--cc        -- required
# no           <--det       -- banks
# banks        <--nsubj     -- wanted
# wanted       <--conj      -- required
# to           <--aux       -- sign
# sign         <--xcomp     -- wanted
# on           <--prt       -- sign
# ,            <--punct     -- had
# Hashcash     <--nsubj     -- had
# had          <--ROOT      -- had
# no           <--det       -- protection
# protection   <--dobj      -- had
# against      <--prep      -- protection
# double       <--amod      -- spending
# -            <--punct     -- spending
# spending     <--pobj      -- against
# ,            <--punct     -- had
# while        <--mark      -- were
# b            <--nsubj     -- were
# -            <--punct     -- were
# money        <--nsubj     -- were
# and          <--cc        -- money
# bit          <--compound  -- gold
# gold         <--conj      -- money
# were         <--advcl     -- had
# not          <--neg       -- were
# resistant    <--acomp     -- were
# to           <--prep      -- resistant
# Sybil        <--compound  -- attacks.[12
# attacks.[12  <--pobj      -- to
# ]            <--punct     -- attacks.[12
#
#
#            <--dep       -- ]
# 2008–2009    <--nummod    -- attacks.[12
# :            <--punct     -- had
# Creation     <--compound  -- page
#
#             <--dep       -- Creation
# External     <--amod      -- page
# image        <--compound  -- image
#
#             <--dep       -- image
# image        <--compound  -- icon
# icon         <--compound  -- page
# Cover        <--compound  -- page
# page         <--dobj      -- had
# of           <--prep      -- page
# The          <--det       -- Times
# Times        <--pobj      -- of
# 3            <--nummod    -- Times
# January      <--npadvmod  -- page
# 2009         <--nummod    -- January
# showing      <--acl       -- page
# the          <--det       -- headline
# headline     <--dobj      -- showing
# used         <--acl       -- headline
# in           <--prep      -- used
# the          <--det       -- logos
# genesis      <--compound  -- block
# block        <--compound  -- logos
#
#
#
#           <--dep       -- block
# Bitcoin      <--compound  -- logos
# logos        <--pobj      -- in
# made         <--acl       -- logos
# by           <--agent     -- made
# Satoshi      <--compound  -- Nakamoto
# Nakamoto     <--pobj      -- by
# in           <--prep      -- made
# 2009         <--pobj      -- in
# (            <--punct     -- left
# left         <--parataxis -- page
# )            <--punct     -- left
# and          <--cc        -- page
# 2010         <--conj      -- page
# (            <--punct     -- right
# right        <--parataxis -- 2010
# )            <--punct     -- right
# .            <--punct     -- had
#
#             <--dep       -- .
# The          <--det       -- name
# domain       <--compound  -- name
# name         <--nsubjpass -- registered
# bitcoin.org  <--appos     -- name
# was          <--auxpass   -- registered
# registered   <--ROOT      -- registered
# on           <--prep      -- registered
# 18           <--nummod    -- 2008.[16
# August       <--compound  -- 2008.[16
# 2008.[16     <--pobj      -- on
# ]            <--punct     -- registered
# On           <--prep      -- posted
# 31           <--nummod    -- October
# October      <--pobj      -- On
# 2008         <--nummod    -- October
# ,            <--punct     -- posted
# a            <--det       -- link
# link         <--nsubjpass -- posted
# to           <--prep      -- link
# a            <--det       -- paper
# white        <--amod      -- paper
# paper        <--pobj      -- to
# authored     <--acl       -- paper
# by           <--agent     -- authored
# Satoshi      <--compound  -- Nakamoto
# Nakamoto     <--pobj      -- by
# titled       <--acl       -- paper
# Bitcoin      <--oprd      -- titled
# :            <--punct     -- link
# A            <--det       -- System
# Peer         <--nmod      -- System
# -            <--punct     -- Peer
# to           <--prep      -- Peer
# -            <--punct     -- to
# Peer         <--pobj      -- to
# Electronic   <--compound  -- System
# Cash         <--compound  -- System
# System       <--nsubjpass -- posted
# was          <--auxpass   -- posted
# posted       <--ROOT      -- posted
# to           <--prep      -- posted
# a            <--det       -- list.[17
# cryptography <--compound  -- mailing
# mailing      <--nmod      -- list.[17
# list.[17     <--pobj      -- to
# ]            <--punct     -- list.[17
# Nakamoto     <--poss      -- identity
# 's           <--case      -- Nakamoto
# identity     <--nsubj     -- remains
# remains      <--ccomp     -- posted
# unknown.[4   <--acomp     -- remains
# ]            <--punct     -- remains
# According    <--prep      -- originated
# to           <--prep      -- According
# computer     <--compound  -- scientist
# scientist    <--compound  -- Narayanan
# Arvind       <--compound  -- Narayanan
# Narayanan    <--pobj      -- to
# ,            <--punct     -- originated
# all          <--det       -- components
# individual   <--amod      -- components
# components   <--nsubj     -- originated
# of           <--prep      -- components
# bitcoin      <--pobj      -- of
# originated   <--ccomp     -- referred
# in           <--prep      -- originated
# earlier      <--amod      -- literature.[12
# academic     <--amod      -- literature.[12
# literature.[12 <--pobj      -- in
# ]            <--punct     -- literature.[12
# Nakamoto     <--poss      -- innovation
# 's           <--case      -- Nakamoto
# innovation   <--nsubj     -- was
# was          <--conj      -- originated
# their        <--poss      -- interplay
# complex      <--amod      -- interplay
# interplay    <--attr      -- was
# resulting    <--acl       -- interplay
# in           <--prep      -- resulting
# the          <--det       -- system
# first        <--amod      -- decentralized
# decentralized <--amod      -- system
# ,            <--punct     -- system
# Sybil        <--nsubj     -- resistant
# resistant    <--amod      -- system
# ,            <--punct     -- fault
# Byzantine    <--amod      -- fault
# fault        <--nmod      -- system
# tolerant     <--amod      -- system
# digital      <--amod      -- system
# cash         <--compound  -- system
# system       <--pobj      -- in
# ,            <--punct     -- referred
# that         <--nsubjpass -- referred
# would        <--aux       -- referred
# eventually   <--advmod    -- referred
# be           <--auxpass   -- referred
# referred     <--ROOT      -- referred
# to           <--prep      -- referred
# as           <--mark      -- reviewed
# the          <--det       -- blockchain.[12][18
# first        <--amod      -- blockchain.[12][18
# blockchain.[12][18 <--pobj      -- as
# ]            <--punct     -- blockchain.[12][18
# Nakamoto     <--poss      -- paper
# 's           <--case      -- Nakamoto
# paper        <--nsubj     -- was
# was          <--auxpass   -- reviewed
# not          <--neg       -- was
# peer         <--acomp     -- was
# reviewed     <--advcl     -- referred
# and          <--cc        -- referred
# was          <--auxpass   -- ignored
# initially    <--advmod    -- ignored
# ignored      <--conj      -- referred
# by           <--agent     -- ignored
# academics    <--pobj      -- by
# ,            <--punct     -- academics
# who          <--nsubj     -- argued
# argued       <--relcl     -- academics
# that         <--mark      -- released
# it           <--nsubj     -- released
# could        <--aux       -- released
# not          <--neg       -- work.[12
# work.[12     <--nmod      -- Nakamoto
# ]            <--punct     -- work.[12
#
#
#            <--dep       -- ]
# Nakamoto     <--nsubj     -- released
# released     <--ccomp     -- argued
# bitcoin      <--dobj      -- released
# as           <--prep      -- released
# open         <--amod      -- source
# -            <--punct     -- source
# source       <--compound  -- software.[19
# software.[19 <--pobj      -- as
# ]            <--punct     -- ignored
# On           <--prep      -- created
# 3            <--nummod    -- January
# January      <--pobj      -- On
# 2009         <--nummod    -- January
# ,            <--punct     -- created
# the          <--det       -- network
# bitcoin      <--compound  -- network
# network      <--nsubjpass -- created
# was          <--auxpass   -- created
# created      <--advcl     -- referred
# when         <--advmod    -- mined
# Nakamoto     <--nsubj     -- mined
# mined        <--advcl     -- created
# the          <--det       -- block
# starting     <--compound  -- block
# block        <--dobj      -- mined
# of           <--prep      -- block
# the          <--det       -- chain
# chain        <--pobj      -- of
# ,            <--punct     -- block
# known        <--acl       -- block
# as           <--prep      -- known
# the          <--det       -- block.[20
# genesis      <--amod      -- block.[20
# block.[20    <--pobj      -- as
# ]            <--punct     -- block
# Embedded     <--acl       -- block
# in           <--prep      -- Embedded
# this         <--det       -- block
# block        <--pobj      -- in
# was          <--conj      -- created
# the          <--det       -- text
# text         <--attr      -- was
# "            <--punct     -- text
# The          <--det       -- Chancellor
# Times        <--nmod      -- Chancellor
# 03           <--nummod    -- Jan/2009
# /            <--punct     -- Jan/2009
# Jan/2009     <--compound  -- Chancellor
# Chancellor   <--appos     -- text
# on           <--prep      -- Chancellor
# brink        <--pobj      -- on
# of           <--prep      -- brink
# second       <--amod      -- bailout
# bailout      <--pobj      -- of
# for          <--prep      -- bailout
# banks        <--pobj      -- for
# "            <--punct     -- bailout
# ,            <--punct     -- Chancellor
# which        <--nsubj     -- is
# is           <--relcl     -- Chancellor
# the          <--det       -- date
# date         <--attr      -- is
# and          <--cc        -- date
# headline     <--conj      -- date
# of           <--prep      -- date
# an           <--det       -- issue
# issue        <--pobj      -- of
# of           <--prep      -- issue
# The          <--det       -- newspaper.[5
# Times        <--compound  -- newspaper.[5
# newspaper.[5 <--pobj      -- of
# ]            <--punct     -- created
# Nine         <--nummod    -- days
# days         <--npadvmod  -- later
# later        <--advmod    -- received
# ,            <--punct     -- received
# Hal          <--compound  -- Finney
# Finney       <--nsubj     -- received
# received     <--ROOT      -- received
# the          <--det       -- transaction
# first        <--amod      -- transaction
# bitcoin      <--compound  -- transaction
# transaction  <--dobj      -- received
# :            <--punct     -- received
# ten          <--nummod    -- bitcoins
# bitcoins     <--appos     -- transaction
# from         <--prep      -- bitcoins
# Nakamoto.[21 <--pobj      -- from
# ]            <--punct     -- bitcoins
# Wei          <--compound  -- Dai
# Dai          <--nsubj     -- were
# and          <--cc        -- Dai
# Nick         <--compound  -- Szabo
# Szabo        <--conj      -- Dai
# were         <--ccomp     -- occurred
# also         <--advmod    -- were
# early        <--advmod    -- supporters.[20
# supporters.[20 <--attr      -- were
# ]            <--punct     -- were
# On           <--prep      -- occurred
# May          <--pobj      -- On
# 22           <--nummod    -- May
# ,            <--punct     -- May
# 2010         <--nummod    -- May
# ,            <--punct     -- occurred
# the          <--det       -- transaction
# first        <--amod      -- transaction
# known        <--amod      -- transaction
# commercial   <--amod      -- transaction
# transaction  <--nsubj     -- occurred
# using        <--acl       -- transaction
# bitcoin      <--dobj      -- using
# occurred     <--ROOT      -- occurred
# when         <--advmod    -- bought
# programmer   <--compound  -- Hanyecz
# Laszlo       <--compound  -- Hanyecz
# Hanyecz      <--nsubj     -- bought
# bought       <--advcl     -- occurred
# two          <--nummod    -- John
# Papa         <--compound  -- John
# John         <--poss      -- pizzas
# 's           <--case      -- John
# pizzas       <--dobj      -- bought
# for          <--prep      -- bought
# ₿            <--pobj      -- for
# 10,000       <--nummod    -- ₿
# ,            <--punct     -- bought
# in           <--prep      -- bought
# what         <--nsubjpass -- celebrated
# would        <--aux       -- celebrated
# later        <--advmod    -- celebrated
# be           <--auxpass   -- celebrated
# celebrated   <--pcomp     -- in
# as           <--prep      -- celebrated
# "            <--punct     -- Day".[22
# Bitcoin      <--compound  -- Pizza
# Pizza        <--compound  -- Day".[22
# Day".[22     <--pobj      -- as
# ]            <--punct     -- Day".[22
# Satoshi      <--nmod      -- developer
# tasked       <--amod      -- developer
# Finnish      <--amod      -- developer
# developer    <--nsubj     -- estimate
# and          <--cc        -- developer
# early        <--amod      -- Bitcoin
# Bitcoin      <--compound  -- contributor
# contributor  <--compound  -- Malmi
# Martti       <--compound  -- Malmi
# Malmi        <--conj      -- developer
# (            <--punct     -- Malmi
# fi           <--appos     -- Malmi
# )            <--punct     -- Malmi
# with         <--prep      -- developer
# creating     <--pcomp     -- with
# content      <--dobj      -- creating
# for          <--prep      -- content
# the          <--det       -- 2010–2012
# bitcoin.org  <--nmod      -- website.[23][24
# website.[23][24 <--nmod      -- 2010–2012
# ]            <--punct     -- website.[23][24
#
#
#            <--dep       -- ]
# 2010–2012    <--pobj      -- for
# :            <--punct     -- developer
# Early        <--amod      -- growth
# growth       <--compound  -- analysts
#
#             <--dep       -- growth
# Blockchain   <--compound  -- analysts
# analysts     <--nsubj     -- estimate
# estimate     <--ROOT      -- estimate
# that         <--mark      -- mined
# Nakamoto     <--nsubj     -- mined
# had          <--aux       -- mined
# mined        <--ccomp     -- estimate
# about        <--advmod    -- million
# one          <--compound  -- million
# million      <--nummod    -- bitcoins[25
# bitcoins[25  <--dobj      -- mined
# ]            <--punct     -- mined
# before       <--prep      -- mined
# disappearing <--pcomp     -- before
# in           <--prep      -- disappearing
# 2010         <--pobj      -- in
# when         <--advmod    -- handed
# he           <--nsubj     -- handed
# handed       <--advcl     -- disappearing
# the          <--det       -- network
# network      <--dobj      -- handed
# alert        <--compound  -- key
# key          <--dobj      -- handed
# and          <--cc        -- key
# control      <--conj      -- key
# of           <--prep      -- key
# the          <--det       -- repository
# code         <--compound  -- repository
# repository   <--pobj      -- of
# over         <--prt       -- handed
# to           <--prep      -- handed
# Gavin        <--compound  -- Andresen
# Andresen     <--pobj      -- to
# .            <--punct     -- estimate
# Andresen     <--nsubj     -- became
# later        <--advmod    -- became
# became       <--ccomp     -- were
# lead         <--amod      -- developer
# developer    <--attr      -- became
# at           <--prep      -- became
# the          <--det       -- Foundation,[26][27
# Bitcoin      <--compound  -- Foundation,[26][27
# Foundation,[26][27 <--pobj      -- at
# ]            <--punct     -- Foundation,[26][27
# an           <--det       -- organization
# organization <--appos     -- Foundation,[26][27
# founded      <--acl       -- organization
# in           <--prep      -- founded
# September    <--pobj      -- in
# 2012         <--nummod    -- September
# to           <--aux       -- promote
# promote      <--advcl     -- founded
# bitcoin.[28  <--dobj      -- promote
# ]            <--punct     -- organization
#
#
#            <--dep       -- ]
# After        <--prep      -- organization
# early        <--amod      -- transactions
# "            <--punct     -- proof
# proof        <--nmod      -- transactions
# -            <--punct     -- proof
# of           <--prep      -- proof
# -            <--punct     -- of
# concept      <--pobj      -- of
# "            <--punct     -- transactions
# transactions <--pobj      -- After
# ,            <--punct     -- were
# the          <--det       -- users
# first        <--amod      -- users
# major        <--amod      -- users
# users        <--nsubj     -- were
# of           <--prep      -- users
# bitcoin      <--pobj      -- of
# were         <--ROOT      -- were
# black        <--amod      -- markets
# markets      <--attr      -- were
# ,            <--punct     -- markets
# such         <--amod      -- as
# as           <--prep      -- markets
# the          <--det       -- Road
# dark         <--amod      -- Road
# web          <--compound  -- Road
# Silk         <--compound  -- Road
# Road         <--pobj      -- as
# .            <--punct     -- were
# During       <--prep      -- accepted
# its          <--poss      -- months
# 30           <--nummod    -- months
# months       <--pobj      -- During
# of           <--prep      -- months
# existence    <--pobj      -- of
# ,            <--punct     -- accepted
# beginning    <--advcl     -- accepted
# in           <--prep      -- beginning
# February     <--pobj      -- in
# 2011         <--nummod    -- February
# ,            <--punct     -- accepted
# Silk         <--compound  -- Road
# Road         <--nsubj     -- accepted
# exclusively  <--advmod    -- accepted
# accepted     <--ROOT      -- accepted
# bitcoins     <--dobj      -- accepted
# as           <--prep      -- accepted
# payment      <--pobj      -- as
# ,            <--punct     -- accepted
# transacting  <--advcl     -- accepted
# ₿            <--npadvmod  -- transacting
# 9.9          <--compound  -- million
# million      <--nummod    -- ₿
# ,            <--punct     -- transacting
# worth        <--amod      -- transacting
# about        <--advmod    -- million.[29
# $            <--quantmod  -- million.[29
# 214          <--compound  -- million.[29
# million.[29  <--npadvmod  -- worth
# ]            <--npadvmod  -- worth
# :            <--punct     -- worth
#              <--dep       -- :
# 222          <--nummod    -- 2013–2014
#
#
#           <--dep       -- 222
# 2013–2014    <--npadvmod  -- worth
# :            <--punct     -- accepted
# First        <--amod      -- actions
# regulatory   <--amod      -- actions
# actions      <--nsubj     -- established
#
#             <--dep       -- actions
# In           <--prep      -- established
# March        <--pobj      -- In
# 2013         <--nummod    -- March
# ,            <--punct     -- established
# the          <--det       -- Network
# US           <--compound  -- Network
# Financial    <--compound  -- Crimes
# Crimes       <--compound  -- Network
# Enforcement  <--compound  -- Network
# Network      <--nsubj     -- established
# (            <--punct     -- Network
# FinCEN       <--appos     -- Network
# )            <--punct     -- Network
# established  <--ccomp     -- seized
# regulatory   <--amod      -- guidelines
# guidelines   <--dobj      -- established
# for          <--prep      -- guidelines
# "            <--punct     -- currencies
# decentralized <--amod      -- currencies
# virtual      <--amod      -- currencies
# currencies   <--pobj      -- for
# "            <--punct     -- currencies
# such         <--amod      -- as
# as           <--prep      -- currencies
# bitcoin      <--pobj      -- as
# ,            <--punct     -- established
# classifying  <--advcl     -- established
# American     <--amod      -- miners
# bitcoin      <--compound  -- miners
# miners       <--dobj      -- classifying
# who          <--nsubj     -- sell
# sell         <--relcl     -- miners
# their        <--poss      -- bitcoins
# generated    <--amod      -- bitcoins
# bitcoins     <--dobj      -- sell
# as           <--prep      -- sell
# money        <--compound  -- services
# services     <--compound  -- businesses
# businesses   <--pobj      -- as
# ,            <--punct     -- businesses
# subject      <--ccomp     -- classifying
# to           <--prep      -- subject
# registration <--pobj      -- to
# and          <--cc        -- registration
# other        <--amod      -- obligations.[30
# legal        <--amod      -- obligations.[30
# obligations.[30 <--conj      -- registration
# ]            <--punct     -- classifying
# In           <--prep      -- seized
# May          <--pobj      -- In
# 2013         <--nummod    -- May
# ,            <--punct     -- seized
# US           <--compound  -- authorities
# authorities  <--nsubj     -- seized
# seized       <--advcl     -- established
# the          <--det       -- exchange
# unregistered <--amod      -- exchange
# exchange     <--dobj      -- seized
# Mt.          <--appos     -- exchange
# Gox.[31      <--punct     -- seized
# ]            <--dobj      -- seized
# In           <--prep      -- seized
# June         <--pobj      -- In
# 2013         <--nummod    -- June
# ,            <--punct     -- seized
# the          <--det       -- Administration
# US           <--compound  -- Administration
# Drug         <--compound  -- Enforcement
# Enforcement  <--compound  -- Administration
# Administration <--nsubj     -- seized
# seized       <--ROOT      -- seized
# ₿            <--npadvmod  -- seized
# 11.02        <--nummod    -- ₿
# from         <--prep      -- seized
# an           <--det       -- individual
# individual   <--pobj      -- from
# attempting   <--acl       -- individual
# to           <--aux       -- use
# use          <--xcomp     -- attempting
# them         <--dobj      -- use
# to           <--aux       -- purchase
# purchase     <--xcomp     -- use
# illicit      <--amod      -- drugs
# drugs        <--dobj      -- purchase
# .            <--punct     -- seized
# This         <--nsubj     -- marked
# marked       <--ROOT      -- marked
# the          <--det       -- time
# first        <--amod      -- time
# time         <--dobj      -- marked
# a            <--det       -- agency
# government   <--compound  -- agency
# agency       <--nsubj     -- seized
# had          <--aux       -- seized
# seized       <--relcl     -- time
# bitcoins.[32 <--dobj      -- seized
# ]            <--punct     -- marked
# The          <--det       -- FBI
# FBI          <--nsubj     -- seized
# seized       <--ROOT      -- seized
# about        <--prep      -- seized
# ₿            <--pobj      -- about
# 30,000       <--nummod    -- ₿
# in           <--prep      -- seized
# October      <--pobj      -- in
# 2013         <--nummod    -- October
# from         <--prep      -- seized
# Silk         <--compound  -- Road
# Road         <--pobj      -- from
# ,            <--punct     -- seized
# following    <--advcl     -- seized
# the          <--det       -- arrest
# arrest       <--pobj      -- following
# of           <--prep      -- arrest
# its          <--poss      -- founder
# founder      <--pobj      -- of
# Ross         <--compound  -- Ulbricht.[33
# Ulbricht.[33 <--appos     -- founder
# ]            <--punct     -- seized
#
#
#            <--dep       -- ]
# In           <--prep      -- prohibited
# December     <--pobj      -- In
# 2013         <--nummod    -- December
# ,            <--punct     -- prohibited
# the          <--det       -- People
# People       <--poss      -- Bank
# 's           <--case      -- People
# Bank         <--nsubj     -- prohibited
# of           <--prep      -- Bank
# China        <--pobj      -- of
# prohibited   <--ROOT      -- prohibited
# Chinese      <--amod      -- institutions
# financial    <--amod      -- institutions
# institutions <--dobj      -- prohibited
# from         <--prep      -- prohibited
# using        <--pcomp     -- from
# bitcoin.[34  <--dobj      -- using
# ]            <--punct     -- prohibited
# After        <--prep      -- been
# the          <--det       -- announcement
# announcement <--pobj      -- After
# ,            <--punct     -- been
# the          <--det       -- value
# value        <--nsubj     -- been
# of           <--prep      -- value
# bitcoin      <--pobj      -- of
# dropped,[35  <--nummod    -- bitcoin
# ]            <--punct     -- value
# and          <--cc        -- value
# Baidu        <--nsubj     -- accepted
# no           <--neg       -- longer
# longer       <--advmod    -- accepted
# accepted     <--conj      -- value
# bitcoins     <--dobj      -- accepted
# for          <--prep      -- bitcoins
# certain      <--amod      -- services.[36
# services.[36 <--pobj      -- for
# ]            <--punct     -- services.[36
# Buying       <--acl       -- services.[36
# real         <--amod      -- world
# -            <--punct     -- world
# world        <--compound  -- goods
# goods        <--dobj      -- Buying
# with         <--prep      -- Buying
# any          <--det       -- currency
# virtual      <--amod      -- currency
# currency     <--pobj      -- with
# had          <--aux       -- been
# been         <--advcl     -- prohibited
# illegal      <--acomp     -- been
# in           <--prep      -- been
# China        <--pobj      -- in
# since        <--prep      -- been
# at           <--advmod    -- least
# least        <--advmod    -- 2009.[37
# 2009.[37     <--nsubj     -- estimated
# ]            <--punct     -- 2009.[37
#
#
#            <--dep       -- ]
# 2015–2019    <--nummod    -- Research
#
#             <--dep       -- 2015–2019
# Research     <--nsubj     -- estimated
# produced     <--acl       -- Research
# by           <--agent     -- produced
# the          <--det       -- University
# University   <--pobj      -- by
# of           <--prep      -- University
# Cambridge    <--pobj      -- of
# estimated    <--pcomp     -- since
# that         <--mark      -- were
# in           <--prep      -- were
# 2017         <--pobj      -- in
# ,            <--punct     -- were
# there        <--expl      -- were
# were         <--ccomp     -- estimated
# 2.9          <--quantmod  -- million
# to           <--quantmod  -- million
# 5.8          <--compound  -- million
# million      <--nummod    -- users
# unique       <--amod      -- users
# users        <--attr      -- were
# using        <--acl       -- users
# a            <--det       -- wallet
# cryptocurrency <--compound  -- wallet
# wallet       <--dobj      -- using
# ,            <--punct     -- were
# most         <--nsubj     -- using
# of           <--prep      -- most
# them         <--pobj      -- of
# using        <--advcl     -- were
# bitcoin.[38  <--dobj      -- using
# ]            <--punct     -- using
# In           <--prep      -- activated
# August       <--pobj      -- In
# 2017         <--nummod    -- August
# ,            <--punct     -- activated
# the          <--det       -- upgrade
# SegWit       <--compound  -- software
# software     <--compound  -- upgrade
# upgrade      <--nsubjpass -- activated
# was          <--auxpass   -- activated
# activated    <--ccomp     -- using
# .            <--punct     -- prohibited
# Segwit       <--nsubjpass -- intended
# was          <--auxpass   -- intended
# intended     <--ROOT      -- intended
# to           <--aux       -- support
# support      <--xcomp     -- intended
# the          <--det       -- Network
# Lightning    <--compound  -- Network
# Network      <--dobj      -- support
# as           <--advmod    -- as
# well         <--advmod    -- as
# as           <--cc        -- support
# improve      <--conj      -- support
# scalability.[39 <--nmod      -- opponents
# ]            <--punct     -- scalability.[39
# SegWit       <--compound  -- opponents
# opponents    <--dobj      -- improve
# ,            <--punct     -- opponents
# who          <--nsubj     -- supported
# supported    <--relcl     -- opponents
# larger       <--amod      -- blocks
# blocks       <--dobj      -- supported
# as           <--prep      -- supported
# a            <--det       -- solution
# scalability  <--compound  -- solution
# solution     <--pobj      -- as
# ,            <--punct     -- opponents
# forked       <--acl       -- opponents
# to           <--aux       -- create
# create       <--xcomp     -- forked
# Bitcoin      <--compound  -- Cash
# Cash         <--dobj      -- create
# ,            <--punct     -- Cash
# one          <--appos     -- Cash
# of           <--prep      -- one
# many         <--amod      -- forks
# forks        <--pobj      -- of
# of           <--prep      -- forks
# bitcoin.[40  <--pobj      -- of
# ]            <--punct     -- one
#
#
#            <--dep       -- ]
# In           <--prep      -- one
# December     <--pobj      -- In
# 2017         <--nummod    -- December
# ,            <--punct     -- Cash
# the          <--det       -- futures
# first        <--amod      -- futures
# futures      <--nsubjpass -- introduced
# on           <--prep      -- futures
# bitcoin      <--pobj      -- on
# was          <--auxpass   -- introduced
# introduced   <--relcl     -- Cash
# by           <--agent     -- introduced
# the          <--det       -- Exchange
# Chicago      <--compound  -- Exchange
# Mercantile   <--compound  -- Exchange
# Exchange     <--pobj      -- by
# (            <--punct     -- Exchange
# CME).[41     <--appos     -- Exchange
# ]            <--punct     -- Exchange
#
#
#            <--dep       -- ]
# In           <--prep      -- crashed
# February     <--pobj      -- In
# 2018         <--nummod    -- February
# ,            <--punct     -- crashed
# the          <--det       -- price
# price        <--nsubj     -- crashed
# crashed      <--conj      -- intended
# after        <--mark      -- imposed
# China        <--nsubj     -- imposed
# imposed      <--advcl     -- fell
# a            <--det       -- ban
# complete     <--amod      -- ban
# ban          <--dobj      -- imposed
# on           <--prep      -- ban
# bitcoin      <--compound  -- trading.[42
# trading.[42  <--pobj      -- on
# ]            <--dep       -- imposed
# The          <--det       -- percentage
# percentage   <--nsubj     -- fell
# of           <--prep      -- percentage
# bitcoin      <--compound  -- trading
# trading      <--pobj      -- of
# in           <--prep      -- percentage
# the          <--det       -- renminbi
# Chinese      <--amod      -- renminbi
# renminbi     <--pobj      -- in
# fell         <--conj      -- intended
# from         <--prep      -- fell
# over         <--quantmod  -- 90
# 90           <--nummod    -- %
# %            <--pobj      -- from
# in           <--prep      -- from
# September    <--pobj      -- in
# 2017         <--nummod    -- September
# to           <--prep      -- fell
# less         <--amod      -- 1
# than         <--quantmod  -- 1
# 1            <--nummod    -- %
# %            <--pobj      -- to
# in           <--prep      -- fell
# June         <--pobj      -- in
# 2018.[43     <--nummod    -- June
# ]            <--punct     -- fell
# During       <--prep      -- affected
# the          <--det       -- year
# same         <--amod      -- year
# year         <--pobj      -- During
# ,            <--punct     -- affected
# bitcoin      <--compound  -- prices
# prices       <--nsubjpass -- affected
# were         <--auxpass   -- affected
# negatively   <--advmod    -- affected
# affected     <--ROOT      -- affected
# by           <--agent     -- affected
# several      <--amod      -- hacks
# hacks        <--pobj      -- by
# or           <--cc        -- hacks
# thefts       <--conj      -- hacks
# from         <--prep      -- hacks
# cryptocurrency <--compound  -- exchanges.[44
# exchanges.[44 <--pobj      -- from
# ]            <--punct     -- exchanges.[44
#
#
#            <--dep       -- ]
# 2020         <--appos     -- exchanges.[44
# –            <--punct     -- exchanges.[44
# present      <--amod      -- price[45
#
#
#            <--dep       -- present
# Bitcoin      <--compound  -- price[45
# price[45     <--appos     -- exchanges.[44
# ]            <--punct     -- price[45
#
#             <--dep       -- ]
# December     <--npadvmod  -- price[45
# 1            <--nummod    -- December
# ,            <--punct     -- December
# 2014         <--nummod    -- December
# –            <--punct     -- December
#
#             <--dep       -- –
# December     <--appos     -- December
# 4            <--nummod    -- December
# ,            <--punct     -- December
# 2024         <--nummod    -- December
#
#             <--dep       -- 2024
# In           <--prep      -- started
# 2020         <--pobj      -- In
# ,            <--punct     -- started
# some         <--det       -- companies
# major        <--amod      -- companies
# companies    <--nsubj     -- started
# and          <--cc        -- companies
# institutions <--conj      -- companies
# started      <--ccomp     -- invested
# to           <--aux       -- acquire
# acquire      <--xcomp     -- started
# bitcoin      <--dobj      -- acquire
# :            <--punct     -- invested
# MicroStrategy <--nsubj     -- invested
# invested     <--ROOT      -- invested
# $            <--quantmod  -- million
# 250          <--compound  -- million
# million      <--dobj      -- invested
# in           <--prep      -- million
# bitcoin      <--pobj      -- in
# as           <--prep      -- invested
# a            <--det       -- Inc.
# treasury     <--compound  -- reserve
# reserve      <--compound  -- Inc.
# asset,[46    <--nmod      -- Inc.
# ]            <--punct     -- asset,[46
# Square       <--nmod      -- Inc.
# ,            <--punct     -- Inc.
# Inc.         <--pobj      -- as
# ,            <--punct     -- Inc.
# $            <--nmod      -- 50
# 50           <--appos     -- Inc.
# million,[47  <--npadvmod  -- 50
# ]            <--punct     -- Inc.
# and          <--cc        -- Inc.
# MassMutual   <--nsubj     -- added
# ,            <--punct     -- MassMutual
# $            <--nmod      -- 100
# 100          <--nummod    -- million.[48
# million.[48  <--appos     -- MassMutual
# ]            <--punct     -- added
# In           <--prep      -- added
# November     <--pobj      -- In
# 2020         <--nummod    -- November
# ,            <--punct     -- added
# PayPal       <--nsubj     -- added
# added        <--conj      -- invested
# support      <--dobj      -- added
# for          <--prep      -- support
# bitcoin      <--pobj      -- for
# in           <--prep      -- support
# the          <--det       -- US.[49
# US.[49       <--pobj      -- in
# ]            <--punct     -- added
#
#
#            <--dep       -- ]
# In           <--prep      -- reached
# February     <--pobj      -- In
# 2021         <--nummod    -- February
# ,            <--punct     -- reached
# bitcoin      <--poss      -- capitalization
# 's           <--case      -- bitcoin
# market       <--compound  -- capitalization
# capitalization <--nsubj     -- reached
# reached      <--ccomp     -- added
# ...
# can          <--aux       -- have
# have         <--ROOT      -- have
# more         <--amod      -- one
# than         <--quantmod  -- one
# one          <--nummod    -- input
# input        <--dobj      -- have
# and          <--cc        -- input
# more         <--amod      -- one
# than         <--quantmod  -- one
# one          <--nummod    -- output.[80
# output.[80   <--conj      -- input
# ]            <--punct     -- have
#
#             <--dep       -- ]
# In           <--prep      -- have
# the          <--det       -- blockchain
# blockchain   <--pobj      -- In
# ,            <--punct     -- linked
# bitcoins     <--nsubjpass -- linked
# are          <--auxpass   -- linked
# linked       <--conj      -- have
# to           <--prep      -- linked
# specific     <--amod      -- strings
# strings      <--pobj      -- to
# called       <--acl       -- strings
# addresses    <--oprd      -- called
# .            <--punct     -- linked
# Most         <--advmod    -- often
# often        <--advmod    -- encodes
# ,            <--punct     -- encodes
# an           <--det       -- address
# address      <--nsubj     -- encodes
# encodes      <--ROOT      -- encodes
# a            <--det       -- hash
# hash         <--dobj      -- encodes
# of           <--prep      -- hash
# a            <--det       -- key
# single       <--amod      -- key
# public       <--amod      -- key
# key          <--pobj      -- of
# .            <--punct     -- encodes
# Creating     <--csubj     -- involves
# such         <--predet    -- address
# an           <--det       -- address
# address      <--dobj      -- Creating
# involves     <--ROOT      -- involves
# generating   <--xcomp     -- involves
# a            <--det       -- key
# random       <--amod      -- key
# private      <--amod      -- key
# key          <--dobj      -- generating
# and          <--cc        -- generating
# then         <--advmod    -- computing
# computing    <--conj      -- generating
# the          <--det       -- address
# corresponding <--amod      -- address
# address      <--dobj      -- computing
# .            <--punct     -- involves
# This         <--det       -- process
# process      <--nsubj     -- is
# is           <--ROOT      -- is
# almost       <--advmod    -- instant
# instant      <--acomp     -- is
# ,            <--punct     -- is
# but          <--cc        -- is
# the          <--det       -- reverse
# reverse      <--nsubj     -- is
# (            <--punct     -- reverse
# finding      <--acl       -- reverse
# the          <--det       -- key
# private      <--amod      -- key
# key          <--dobj      -- finding
# for          <--prep      -- key
# a            <--det       -- address
# given        <--amod      -- address
# address      <--pobj      -- for
# )            <--punct     -- reverse
# is           <--conj      -- is
# nearly       <--advmod    -- impossible.[6
# impossible.[6 <--attr      -- is
# ]            <--punct     -- is
# :            <--punct     -- is
#              <--dep       -- :
# ch           <--attr      -- is
# .            <--attr      -- is
# 4            <--nummod    -- Publishing
#              <--dep       -- 4
# Publishing   <--csubj     -- risk
# such         <--predet    -- address
# a            <--det       -- address
# bitcoin      <--compound  -- address
# address      <--dobj      -- Publishing
# does         <--aux       -- risk
# not          <--neg       -- risk
# risk         <--ccomp     -- is
# its          <--poss      -- key
# private      <--amod      -- key
# key          <--dobj      -- risk
# ,            <--punct     -- is
# and          <--cc        -- is
# it           <--nsubj     -- is
# is           <--conj      -- is
# extremely    <--advmod    -- unlikely
# unlikely     <--acomp     -- is
# to           <--aux       -- generate
# accidentally <--advmod    -- generate
# generate     <--xcomp     -- unlikely
# a            <--det       -- key
# used         <--amod      -- key
# key          <--dobj      -- generate
# with         <--prep      -- key
# funds        <--pobj      -- with
# .            <--punct     -- is
# To           <--aux       -- use
# use          <--advcl     -- need
# bitcoins     <--dobj      -- use
# ,            <--punct     -- need
# owners       <--nsubj     -- need
# need         <--ccomp     -- encode
# their        <--poss      -- key
# private      <--amod      -- key
# key          <--dobj      -- need
# to           <--prep      -- key
# digitally    <--advmod    -- sign
# sign         <--compound  -- transactions
# transactions <--pobj      -- to
# ,            <--punct     -- transactions
# which        <--nsubjpass -- verified
# are          <--auxpass   -- verified
# verified     <--relcl     -- transactions
# by           <--agent     -- verified
# the          <--det       -- network
# network      <--pobj      -- by
# using        <--acl       -- network
# the          <--det       -- key
# public       <--amod      -- key
# key          <--dobj      -- using
# ,            <--punct     -- need
# keeping      <--advcl     -- encode
# the          <--det       -- secret.[6
# private      <--amod      -- secret.[6
# key          <--amod      -- secret.[6
# secret.[6    <--dobj      -- keeping
# ]            <--punct     -- keeping
# :            <--punct     -- ch
#              <--dep       -- :
# ch           <--oprd      -- keeping
# .            <--oprd      -- keeping
# 5            <--nummod    -- address
#              <--dep       -- 5
# An           <--det       -- address
# address      <--nsubj     -- encode
# may          <--aux       -- encode
# encode       <--ROOT      -- encode
# the          <--det       -- hash
# hash         <--dobj      -- encode
# of           <--prep      -- hash
# a            <--det       -- script
# bitcoin      <--compound  -- script
# script       <--pobj      -- of
# that         <--nsubj     -- specifies
# specifies    <--relcl     -- script
# more         <--advmod    -- complex
# complex      <--amod      -- requirements
# requirements <--dobj      -- specifies
# to           <--aux       -- spend
# spend        <--acl       -- requirements
# the          <--det       -- funds
# funds        <--dobj      -- spend
# .            <--punct     -- encode
# One          <--nummod    -- example
# common       <--amod      -- example
# example      <--nsubj     -- is
# is           <--ROOT      -- is
# "            <--punct     -- is
# multisig     <--attr      -- is
# "            <--punct     -- multisig
# ,            <--punct     -- multisig
# in           <--prep      -- sign
# which        <--pobj      -- in
# multiple     <--amod      -- keys
# distinct     <--amod      -- keys
# private      <--amod      -- keys
# keys         <--nsubj     -- sign
# must         <--aux       -- sign
# mutually     <--advmod    -- sign
# sign         <--relcl     -- multisig
# any          <--det       -- transaction
# transaction  <--dobj      -- sign
# that         <--nsubj     -- attempts
# attempts     <--relcl     -- transaction
# to           <--aux       -- spend
# spend        <--xcomp     -- attempts
# the          <--det       -- funds.[6
# funds.[6     <--dobj      -- spend
# ]            <--punct     -- is
# :            <--punct     -- is
#              <--dep       -- :
# ch           <--attr      -- is
# .            <--attr      -- is
# 7            <--nummod    -- transactions
#
#
#           <--dep       -- 7
# Bitcoin      <--compound  -- transactions
# transactions <--nsubj     -- use
# use          <--ccomp     -- is
# a            <--det       -- scripting
# Forth        <--npadvmod  -- like
# -            <--punct     -- like
# like         <--amod      -- scripting
# scripting    <--dobj      -- use
# language,[6  <--dobj      -- scripting
# ]            <--punct     -- use
# :            <--punct     -- use
#              <--dep       -- :
# ch           <--punct     -- is
# .            <--attr      -- is
# 5            <--nummod    -- .
#              <--dep       -- 5
# involving    <--advcl     -- is
# one          <--nummod    -- inputs
# or           <--cc        -- one
# more         <--conj      -- one
# inputs       <--dobj      -- involving
# and          <--cc        -- inputs
# outputs      <--conj      -- inputs
# .            <--punct     -- is
# When         <--advmod    -- sending
# sending      <--advcl     -- specifies
# bitcoins     <--dobj      -- sending
# ,            <--punct     -- specifies
# a            <--det       -- user
# user         <--nsubj     -- specifies
# specifies    <--ROOT      -- specifies
# the          <--det       -- recipients
# recipients   <--poss      -- addresses
# '            <--case      -- recipients
# addresses    <--dobj      -- specifies
# and          <--cc        -- addresses
# the          <--det       -- amount
# amount       <--conj      -- addresses
# for          <--prep      -- amount
# each         <--det       -- output
# output       <--pobj      -- for
# .            <--punct     -- specifies
# This         <--nsubj     -- allows
# allows       <--ROOT      -- allows
# sending      <--xcomp     -- allows
# bitcoins     <--dobj      -- sending
# to           <--dative    -- sending
# several      <--amod      -- recipients
# recipients   <--pobj      -- to
# in           <--prep      -- sending
# a            <--det       -- transaction
# single       <--amod      -- transaction
# transaction  <--pobj      -- in
# .            <--punct     -- allows
# To           <--aux       -- prevent
# prevent      <--advcl     -- refer
# double       <--amod      -- spending
# -            <--punct     -- spending
# spending     <--dobj      -- prevent
# ,            <--punct     -- refer
# each         <--det       -- input
# input        <--nsubj     -- refer
# must         <--aux       -- refer
# refer        <--ccomp     -- is
# to           <--prep      -- refer
# a            <--det       -- output
# previous     <--amod      -- output
# unspent      <--amod      -- output
# output       <--pobj      -- to
# in           <--prep      -- output
# the          <--det       -- blockchain.[80
# blockchain.[80 <--pobj      -- in
# ]            <--punct     -- refer
# Using        <--csubj     -- is
# multiple     <--amod      -- inputs
# inputs       <--dobj      -- Using
# is           <--ROOT      -- is
# similar      <--acomp     -- is
# to           <--prep      -- similar
# using        <--pcomp     -- to
# multiple     <--amod      -- coins
# coins        <--dobj      -- using
# in           <--prep      -- using
# a            <--det       -- transaction
# cash         <--compound  -- transaction
# transaction  <--pobj      -- in
# .            <--punct     -- is
# As           <--prep      -- exceed
# in           <--prep      -- As
# a            <--det       -- transaction
# cash         <--compound  -- transaction
# transaction  <--pobj      -- in
# ,            <--punct     -- exceed
# the          <--det       -- sum
# sum          <--nsubj     -- exceed
# of           <--prep      -- sum
# inputs       <--pobj      -- of
# can          <--aux       -- exceed
# exceed       <--ROOT      -- exceed
# the          <--det       -- sum
# intended     <--amod      -- sum
# sum          <--dobj      -- exceed
# of           <--prep      -- sum
# payments     <--pobj      -- of
# .            <--punct     -- exceed
# In           <--prep      -- return
# such         <--predet    -- case
# a            <--det       -- case
# case         <--pobj      -- In
# ,            <--punct     -- return
# an           <--det       -- output
# additional   <--amod      -- output
# output       <--nsubj     -- return
# can          <--aux       -- return
# return       <--ccomp     -- become
# the          <--det       -- change
# change       <--dobj      -- return
# back         <--advmod    -- return
# to           <--prep      -- back
# the          <--det       -- payer.[80
# payer.[80    <--pobj      -- to
# ]            <--punct     -- return
# Unallocated  <--amod      -- input
# input        <--compound  -- satoshis
# satoshis     <--nsubj     -- become
# in           <--prep      -- satoshis
# the          <--det       -- transaction
# transaction  <--pobj      -- in
# become       <--ccomp     -- lost
# the          <--det       -- transaction
# transaction  <--attr      -- become
# fee.[80      <--nummod    -- transaction
# ]            <--punct     -- become
#
#
#            <--dep       -- ]
# Losing       <--advcl     -- become
# a            <--det       -- means
# private      <--amod      -- means
# key          <--amod      -- means
# means        <--dobj      -- Losing
# losing       <--acl       -- means
# access       <--dobj      -- losing
# to           <--prep      -- access
# the          <--det       -- bitcoins
# bitcoins     <--pobj      -- to
# ,            <--punct     -- Losing
# with         <--prep      -- Losing
# no           <--det       -- proof
# other        <--amod      -- proof
# proof        <--pobj      -- with
# of           <--prep      -- proof
# ownership    <--pobj      -- of
# accepted     <--acl       -- ownership
# by           <--agent     -- accepted
# the          <--det       -- protocol.[29
# protocol.[29 <--pobj      -- by
# ]            <--dobj      -- Losing
# For          <--prep      -- Losing
# instance     <--pobj      -- For
# ,            <--punct     -- Losing
# in           <--prep      -- Losing
# 2013         <--pobj      -- in
# ,            <--punct     -- lost
# a            <--det       -- user
# user         <--nsubj     -- lost
# lost         <--ROOT      -- lost
# ₿            <--dobj      -- lost
# 7,500        <--nummod    -- ₿
# ,            <--punct     -- ₿
# valued       <--advcl     -- lost
# at           <--prep      -- valued
# US$          <--quantmod  -- million
# 7.5          <--compound  -- million
# million      <--pobj      -- at
# ,            <--punct     -- valued
# by           <--prep      -- valued
# accidentally <--advmod    -- discarding
# discarding   <--pcomp     -- by
# a            <--det       -- drive
# hard         <--amod      -- drive
# drive        <--dobj      -- discarding
# with         <--prep      -- drive
# the          <--det       -- key.[81
# private      <--amod      -- key.[81
# key.[81      <--pobj      -- with
# ]            <--punct     -- lost
# It           <--nsubjpass -- estimated
# is           <--auxpass   -- estimated
# estimated    <--ROOT      -- estimated
# that         <--mark      -- are
# around       <--advmod    -- 20
# 20           <--nummod    -- %
# %            <--nsubj     -- are
# of           <--prep      -- %
# all          <--det       -- bitcoins
# bitcoins     <--pobj      -- of
# are          <--ccomp     -- estimated
# lost.[82     <--acomp     -- are
# ]            <--punct     -- are
# The          <--det       -- key
# private      <--amod      -- key
# key          <--nsubjpass -- kept
# must         <--aux       -- kept
# also         <--advmod    -- kept
# be           <--auxpass   -- kept
# kept         <--conj      -- estimated
# secret       <--oprd      -- kept
# as           <--prep      -- secret
# its          <--poss      -- exposure
# exposure     <--pobj      -- as
# ,            <--punct     -- exposure
# such         <--amod      -- as
# as           <--prep      -- exposure
# through      <--prep      -- as
# a            <--det       -- breach
# data         <--compound  -- breach
# breach       <--pobj      -- through
# ,            <--punct     -- exposure
# can          <--aux       -- lead
# lead         <--ccomp     -- estimated
# to           <--prep      -- lead
# theft        <--pobj      -- to
# of           <--prep      -- theft
# the          <--det       -- bitcoins.[6
# associated   <--amod      -- bitcoins.[6
# bitcoins.[6  <--pobj      -- of
# ]            <--punct     -- lead
# :            <--punct     -- ch
#              <--dep       -- :
# ch           <--npadvmod  -- estimated
# .            <--punct     -- estimated
# 10           <--nummod    -- [
#              <--dep       -- 10
# [            <--dep       -- stolen
# 83           <--punct     -- [
# ]            <--dep       -- As
# As           <--prep      -- stolen
# of           <--prep      -- As
# December     <--pobj      -- of
# 2017         <--nummod    -- December
# ,            <--punct     -- stolen
# approximately <--advmod    -- stolen
# ₿            <--nsubjpass -- stolen
# 980,000      <--nsubjpass -- stolen
# had          <--aux       -- stolen
# been         <--auxpass   -- stolen
# stolen       <--ROOT      -- stolen
# from         <--prep      -- stolen
# cryptocurrency <--compound  -- exchanges.[84
# exchanges.[84 <--pobj      -- from
# ]            <--pobj      -- from
#
#             <--dep       -- ]

# %% [markdown]
# #Sentence wise grammar parsing

# %%
for sent in doc.sents:
    print("Sentence:", sent.text)
    for token in sent:
        print(f"  {token.text:15} {token.pos_:10} {token.dep_:10} --> {token.head.text}")
    print()
# Out:
# Sentence:
# Bitcoin (abbreviation: BTC; sign: ₿) is the first decentralized cryptocurrency.
#
#                SPACE      dep        --> Bitcoin
#   Bitcoin         PROPN      dep        --> sign
#   (               PUNCT      punct      --> Bitcoin
#   abbreviation    NOUN       appos      --> Bitcoin
#   :               PUNCT      punct      --> abbreviation
#   BTC             NOUN       appos      --> abbreviation
#   ;               PUNCT      punct      --> sign
#   sign            NOUN       nsubj      --> is
#   :               PUNCT      punct      --> sign
#   ₿               PROPN      npadvmod   --> sign
#   )               PUNCT      punct      --> sign
#   is              AUX        ROOT       --> is
#   the             DET        det        --> cryptocurrency
#   first           ADJ        amod       --> cryptocurrency
#   decentralized   VERB       amod       --> cryptocurrency
#   cryptocurrency  NOUN       attr       --> is
#   .               PUNCT      punct      --> is
#
# Sentence: Based on a free-market ideology, bitcoin was invented in 2008 when an unknown entity published a white paper under the pseudonym of Satoshi Nakamoto.[4] Use of bitcoin as a currency began in 2009,[5] with the release of its open-source implementation.[6]: ch. 1  From 2021 to 2025, El Salvador adopted it as legal tender currency before revoking it.[7][8][9] As bitcoin is pseudonymous, its use by criminals has attracted the attention of regulators, leading to its ban by several countries.[10]
#
# Bitcoin works through the collaboration of computers, each of which acts as a node in the peer-to-peer bitcoin network.
#   Based           VERB       prep       --> invented
#   on              ADP        prep       --> Based
#   a               DET        det        --> ideology
#   free            ADJ        amod       --> market
#   -               PUNCT      punct      --> market
#   market          NOUN       compound   --> ideology
#   ideology        NOUN       pobj       --> on
#   ,               PUNCT      punct      --> invented
#   bitcoin         NOUN       nsubjpass  --> invented
#   was             AUX        auxpass    --> invented
#   invented        VERB       ccomp      --> adopted
#   in              ADP        prep       --> invented
#   2008            NUM        pobj       --> in
#   when            SCONJ      advmod     --> published
#   an              DET        det        --> entity
#   unknown         ADJ        amod       --> entity
#   entity          NOUN       nsubj      --> published
#   published       VERB       advcl      --> invented
#   a               DET        det        --> paper
#   white           ADJ        amod       --> paper
#   paper           NOUN       dobj       --> published
#   under           ADP        prep       --> published
#   the             DET        det        --> pseudonym
#   pseudonym       NOUN       pobj       --> under
#   of              ADP        prep       --> pseudonym
#   Satoshi         PROPN      compound   --> Nakamoto.[4
#   Nakamoto.[4     PROPN      nmod       --> Use
#   ]               PUNCT      punct      --> Nakamoto.[4
#   Use             PROPN      pobj       --> of
#   of              ADP        prep       --> Use
#   bitcoin         NOUN       pobj       --> of
#   as              ADP        prep       --> Use
#   a               DET        det        --> currency
#   currency        NOUN       pobj       --> as
#   began           VERB       conj       --> invented
#   in              ADP        prep       --> began
#   2009,[5         NUM        pobj       --> in
#   ]               PUNCT      punct      --> began
#   with            ADP        prep       --> began
#   the             DET        det        --> release
#   release         NOUN       pobj       --> with
#   of              ADP        prep       --> release
#   its             PRON       poss       --> implementation.[6
#   open            ADJ        amod       --> source
#   -               PUNCT      punct      --> source
#   source          NOUN       compound   --> implementation.[6
#   implementation.[6 NOUN       pobj       --> of
#   ]               PUNCT      punct      --> release
#   :               PUNCT      punct      --> ch
#                   SPACE      dep        --> :
#   ch              NOUN       appos      --> bitcoin
#   .               PROPN      npadvmod   --> invented
#   1               NUM        punct      --> invented
#                   SPACE      dep        --> 1
#   From            ADP        prep       --> invented
#   2021            NUM        pobj       --> From
#   to              ADP        prep       --> From
#   2025            NUM        pobj       --> to
#   ,               PUNCT      punct      --> adopted
#   El              PROPN      compound   --> Salvador
#   Salvador        PROPN      nsubj      --> adopted
#   adopted         VERB       ROOT       --> adopted
#   it              PRON       dobj       --> adopted
#   as              ADP        prep       --> adopted
#   legal           ADJ        amod       --> currency
#   tender          NOUN       compound   --> currency
#   currency        NOUN       pobj       --> as
#   before          ADP        prep       --> adopted
#   revoking        VERB       pcomp      --> before
#   it.[7][8][9     PROPN      dobj       --> revoking
#   ]               PUNCT      punct      --> adopted
#   As              SCONJ      mark       --> is
#   bitcoin         NOUN       nsubj      --> is
#   is              AUX        advcl      --> attracted
#   pseudonymous    ADJ        acomp      --> is
#   ,               PUNCT      punct      --> attracted
#   its             PRON       poss       --> use
#   use             NOUN       nsubj      --> attracted
#   by              ADP        prep       --> use
#   criminals       NOUN       pobj       --> by
#   has             AUX        aux        --> attracted
#   attracted       VERB       conj       --> adopted
#   the             DET        det        --> attention
#   attention       NOUN       dobj       --> attracted
#   of              ADP        prep       --> attention
#   regulators      NOUN       pobj       --> of
#   ,               PUNCT      punct      --> attracted
#   leading         VERB       advcl      --> attracted
#   to              ADP        prep       --> leading
#   its             PRON       poss       --> ban
#   ban             NOUN       pobj       --> to
#   by              ADP        agent      --> leading
#   several         ADJ        amod       --> countries.[10
#   countries.[10   PROPN      nmod       --> Bitcoin
#   ]               PUNCT      punct      --> Bitcoin
#
#
#               SPACE      dep        --> ]
#   Bitcoin         PROPN      nsubj      --> works
#   works           VERB       ccomp      --> leading
#   through         ADP        prep       --> works
#   the             DET        det        --> collaboration
#   collaboration   NOUN       pobj       --> through
#   of              ADP        prep       --> collaboration
#   computers       NOUN       pobj       --> of
#   ,               PUNCT      punct      --> collaboration
#   each            PRON       nsubj      --> acts
#   of              ADP        prep       --> each
#   which           PRON       pobj       --> of
#   acts            VERB       relcl      --> collaboration
#   as              ADP        prep       --> acts
#   a               DET        det        --> node
#   node            NOUN       pobj       --> as
#   in              ADP        prep       --> node
#   the             DET        det        --> network
#   peer            NOUN       nmod       --> network
#   -               PUNCT      punct      --> peer
#   to              ADP        prep       --> peer
#   -               PUNCT      punct      --> to
#   peer            NOUN       pobj       --> to
#   bitcoin         NOUN       compound   --> network
#   network         NOUN       pobj       --> in
#   .               PUNCT      punct      --> adopted
#
# Sentence: Each node maintains an independent copy of a public distributed ledger of transactions, called a blockchain, without central oversight.
#   Each            DET        det        --> node
#   node            NOUN       nsubj      --> maintains
#   maintains       VERB       ROOT       --> maintains
#   an              DET        det        --> copy
#   independent     ADJ        amod       --> copy
#   copy            NOUN       dobj       --> maintains
#   of              ADP        prep       --> copy
#   a               DET        det        --> ledger
#   public          ADJ        amod       --> ledger
#   distributed     VERB       amod       --> ledger
#   ledger          NOUN       pobj       --> of
#   of              ADP        prep       --> ledger
#   transactions    NOUN       pobj       --> of
#   ,               PUNCT      punct      --> maintains
#   called          VERB       conj       --> maintains
#   a               DET        det        --> blockchain
#   blockchain      NOUN       oprd       --> called
#   ,               PUNCT      punct      --> called
#   without         ADP        prep       --> called
#   central         ADJ        amod       --> oversight
#   oversight       NOUN       pobj       --> without
#   .               PUNCT      punct      --> maintains
#
# Sentence: Transactions are validated through the use of cryptography, preventing one person from spending another person's bitcoin, as long as the owner of the bitcoin keeps certain sensitive data secret.[6]: ch. 5
#
# Consensus between nodes about the content of the blockchain is achieved using a computationally intensive process based on proof of work, called mining, which is performed by purpose-built computers.[6]: ch. 12  Mining consumes large quantities of electricity and has been criticized for its environmental impact.[11]
#
# History
# Main article: History of bitcoin
# Background
# Before bitcoin, several digital cash technologies were released, starting with David Chaum's ecash in the 1980s.[12]
#   Transactions    NOUN       nsubjpass  --> validated
#   are             AUX        auxpass    --> validated
#   validated       VERB       ccomp      --> achieved
#   through         ADP        prep       --> validated
#   the             DET        det        --> use
#   use             NOUN       pobj       --> through
#   of              ADP        prep       --> use
#   cryptography    NOUN       pobj       --> of
#   ,               PUNCT      punct      --> validated
#   preventing      VERB       advcl      --> validated
#   one             NUM        nummod     --> person
#   person          NOUN       dobj       --> preventing
#   from            ADP        prep       --> preventing
#   spending        VERB       pcomp      --> from
#   another         DET        det        --> person
#   person          NOUN       poss       --> bitcoin
#   's              PART       case       --> person
#   bitcoin         NOUN       dobj       --> spending
#   ,               PUNCT      punct      --> validated
#   as              ADV        advmod     --> long
#   long            ADV        advmod     --> validated
#   as              SCONJ      mark       --> keeps
#   the             DET        det        --> owner
#   owner           NOUN       nsubj      --> keeps
#   of              ADP        prep       --> owner
#   the             DET        det        --> bitcoin
#   bitcoin         NOUN       pobj       --> of
#   keeps           VERB       advcl      --> long
#   certain         ADJ        amod       --> secret.[6
#   sensitive       ADJ        amod       --> secret.[6
#   data            NOUN       compound   --> secret.[6
#   secret.[6       NOUN       dobj       --> keeps
#   ]               PUNCT      punct      --> validated
#   :               PUNCT      punct      --> validated
#                   SPACE      dep        --> :
#   ch              NOUN       nsubjpass  --> achieved
#   .               PROPN      nsubjpass  --> achieved
#   5               NUM        nummod     --> Consensus
#
#
#              SPACE      dep        --> 5
#   Consensus       PROPN      nsubjpass  --> achieved
#   between         ADP        prep       --> Consensus
#   nodes           NOUN       pobj       --> between
#   about           ADP        prep       --> nodes
#   the             DET        det        --> content
#   content         NOUN       pobj       --> about
#   of              ADP        prep       --> content
#   the             DET        det        --> blockchain
#   blockchain      NOUN       pobj       --> of
#   is              AUX        auxpass    --> achieved
#   achieved        VERB       ROOT       --> achieved
#   using           VERB       xcomp      --> achieved
#   a               DET        det        --> process
#   computationally ADV        advmod     --> intensive
#   intensive       ADJ        amod       --> process
#   process         NOUN       dobj       --> using
#   based           VERB       acl        --> process
#   on              ADP        prep       --> based
#   proof           NOUN       pobj       --> on
#   of              ADP        prep       --> proof
#   work            NOUN       pobj       --> of
#   ,               PUNCT      punct      --> work
#   called          VERB       acl        --> proof
#   mining          NOUN       oprd       --> called
#   ,               PUNCT      punct      --> proof
#   which           PRON       nsubjpass  --> performed
#   is              AUX        auxpass    --> performed
#   performed       VERB       relcl      --> proof
#   by              ADP        agent      --> performed
#   purpose         NOUN       npadvmod   --> built
#   -               PUNCT      punct      --> built
#   built           VERB       amod       --> computers.[6
#   computers.[6    NOUN       pobj       --> by
#   ]               PUNCT      punct      --> achieved
#   :               PUNCT      punct      --> achieved
#                   SPACE      dep        --> :
#   ch              NOUN       appos      --> ch
#   .               PROPN      npadvmod   --> achieved
#   12              NUM        nummod     --> Mining
#                   SPACE      dep        --> 12
#   Mining          PROPN      nsubj      --> consumes
#   consumes        VERB       conj       --> achieved
#   large           ADJ        amod       --> quantities
#   quantities      NOUN       dobj       --> consumes
#   of              ADP        prep       --> quantities
#   electricity     NOUN       pobj       --> of
#   and             CCONJ      cc         --> consumes
#   has             AUX        aux        --> criticized
#   been            AUX        auxpass    --> criticized
#   criticized      VERB       conj       --> consumes
#   for             ADP        prep       --> criticized
#   its             PRON       poss       --> article
#   environmental   ADJ        amod       --> article
#   impact.[11      NOUN       nmod       --> article
#   ]               PUNCT      dep        --> impact.[11
#
#
#               SPACE      dep        --> ]
#   History         NOUN       compound   --> article
#
#                SPACE      dep        --> History
#   Main            ADJ        amod       --> article
#   article         NOUN       pobj       --> for
#   :               PUNCT      punct      --> article
#   History         NOUN       nsubjpass  --> released
#   of              ADP        prep       --> History
#   bitcoin         NOUN       compound   --> Background
#
#                SPACE      dep        --> bitcoin
#   Background      NOUN       pobj       --> of
#
#                SPACE      dep        --> Background
#   Before          ADP        prep       --> History
#   bitcoin         NOUN       pobj       --> Before
#   ,               PUNCT      punct      --> History
#   several         ADJ        amod       --> technologies
#   digital         ADJ        amod       --> technologies
#   cash            NOUN       compound   --> technologies
#   technologies    NOUN       conj       --> History
#   were            AUX        auxpass    --> released
#   released        VERB       acl        --> article
#   ,               PUNCT      punct      --> released
#   starting        VERB       advcl      --> released
#   with            ADP        prep       --> starting
#   David           PROPN      compound   --> Chaum
#   Chaum           PROPN      poss       --> ecash
#   's              PART       case       --> Chaum
#   ecash           NOUN       pobj       --> with
#   in              ADP        prep       --> starting
#   the             DET        det        --> 1980s.[12
#   1980s.[12       NOUN       pobj       --> in
#   ]               PUNCT      punct      --> article
#
# Sentence: The idea that solutions to computational puzzles could have some value was first proposed by cryptographers Cynthia Dwork and Moni Naor in 1992.[13][12]
#   The             DET        det        --> idea
#   idea            NOUN       nsubjpass  --> proposed
#   that            SCONJ      mark       --> have
#   solutions       NOUN       nsubj      --> have
#   to              ADP        prep       --> solutions
#   computational   ADJ        amod       --> puzzles
#   puzzles         NOUN       pobj       --> to
#   could           AUX        aux        --> have
#   have            AUX        acl        --> idea
#   some            DET        det        --> value
#   value           NOUN       dobj       --> have
#   was             AUX        auxpass    --> proposed
#   first           ADV        advmod     --> proposed
#   proposed        VERB       ROOT       --> proposed
#   by              ADP        agent      --> proposed
#   cryptographers  NOUN       compound   --> Dwork
#   Cynthia         PROPN      compound   --> Dwork
#   Dwork           PROPN      pobj       --> by
#   and             CCONJ      cc         --> Dwork
#   Moni            PROPN      compound   --> Naor
#   Naor            PROPN      conj       --> Dwork
#   in              ADP        prep       --> proposed
#   1992.[13][12    NUM        pobj       --> in
#   ]               PUNCT      punct      --> proposed
#
# Sentence: The concept was independently rediscovered by Adam Back who developed Hashcash, a proof-of-work scheme for spam control in 1997.[12]
#   The             DET        det        --> concept
#   concept         NOUN       nsubjpass  --> rediscovered
#   was             AUX        auxpass    --> rediscovered
#   independently   ADV        advmod     --> rediscovered
#   rediscovered    VERB       ROOT       --> rediscovered
#   by              ADP        agent      --> rediscovered
#   Adam            PROPN      compound   --> Back
#   Back            ADV        pobj       --> by
#   who             PRON       nsubj      --> developed
#   developed       VERB       relcl      --> Back
#   Hashcash        PROPN      dobj       --> developed
#   ,               PUNCT      punct      --> Hashcash
#   a               DET        det        --> scheme
#   proof           NOUN       nmod       --> scheme
#   -               PUNCT      punct      --> proof
#   of              ADP        prep       --> proof
#   -               PUNCT      punct      --> of
#   work            NOUN       pobj       --> of
#   scheme          NOUN       appos      --> Hashcash
#   for             ADP        prep       --> scheme
#   spam            NOUN       compound   --> control
#   control         NOUN       pobj       --> for
#   in              ADP        prep       --> scheme
#   1997.[12        NUM        pobj       --> in
#   ]               PUNCT      punct      --> rediscovered
#
# Sentence: The first proposals for distributed digital scarcity-based cryptocurrencies came from cypherpunks Wei Dai (b-money) and Nick Szabo (bit gold) in 1998.[14]
#   The             DET        det        --> proposals
#   first           ADJ        amod       --> proposals
#   proposals       NOUN       nsubj      --> came
#   for             ADP        prep       --> proposals
#   distributed     VERB       amod       --> cryptocurrencies
#   digital         ADJ        amod       --> cryptocurrencies
#   scarcity        NOUN       npadvmod   --> based
#   -               PUNCT      punct      --> based
#   based           VERB       amod       --> cryptocurrencies
#   cryptocurrencies NOUN       pobj       --> for
#   came            VERB       ROOT       --> came
#   from            ADP        prep       --> came
#   cypherpunks     NOUN       compound   --> Dai
#   Wei             PROPN      compound   --> Dai
#   Dai             PROPN      pobj       --> from
#   (               PUNCT      punct      --> Dai
#   b               NOUN       appos      --> Dai
#   -               PUNCT      punct      --> b
#   money           NOUN       conj       --> b
#   )               PUNCT      punct      --> Dai
#   and             CCONJ      cc         --> Dai
#   Nick            PROPN      compound   --> Szabo
#   Szabo           PROPN      conj       --> Dai
#   (               PUNCT      punct      --> gold
#   bit             NOUN       compound   --> gold
#   gold            NOUN       appos      --> Szabo
#   )               PUNCT      punct      --> gold
#   in              ADP        prep       --> came
#   1998.[14        NUM        pobj       --> in
#   ]               PUNCT      punct      --> came
#
# Sentence: In 2004, Hal Finney developed the first currency based on reusable proof of work.[15] These various attempts were not successful:[12] Chaum's concept required centralized control and no banks wanted to sign on, Hashcash had no protection against double-spending, while b-money and bit gold were not resistant to Sybil attacks.[12]
#
# 2008–2009: Creation
# External image
# image icon Cover page of The Times 3 January 2009 showing the headline used in the genesis block
#
#
# Bitcoin logos made by Satoshi Nakamoto in 2009 (left) and 2010 (right).
#
#   In              ADP        prep       --> developed
#   2004            NUM        pobj       --> In
#   ,               PUNCT      punct      --> developed
#   Hal             PROPN      compound   --> Finney
#   Finney          PROPN      nsubj      --> developed
#   developed       VERB       ccomp      --> had
#   the             DET        det        --> currency
#   first           ADJ        amod       --> currency
#   currency        NOUN       dobj       --> developed
#   based           VERB       prep       --> developed
#   on              ADP        prep       --> based
#   reusable        ADJ        amod       --> proof
#   proof           NOUN       pobj       --> on
#   of              ADP        prep       --> proof
#   work.[15        NOUN       pobj       --> of
#   ]               PUNCT      punct      --> developed
#   These           DET        det        --> attempts
#   various         ADJ        amod       --> attempts
#   attempts        NOUN       nsubj      --> were
#   were            AUX        ccomp      --> developed
#   not             PART       neg        --> were
#   successful:[12  X          acomp      --> were
#   ]               X          dep        --> were
#   Chaum           PROPN      poss       --> concept
#   's              PART       case       --> Chaum
#   concept         NOUN       nsubj      --> required
#   required        VERB       conj       --> developed
#   centralized     ADJ        amod       --> control
#   control         NOUN       dobj       --> required
#   and             CCONJ      cc         --> required
#   no              DET        det        --> banks
#   banks           NOUN       nsubj      --> wanted
#   wanted          VERB       conj       --> required
#   to              PART       aux        --> sign
#   sign            VERB       xcomp      --> wanted
#   on              ADP        prt        --> sign
#   ,               PUNCT      punct      --> had
#   Hashcash        PROPN      nsubj      --> had
#   had             VERB       ROOT       --> had
#   no              DET        det        --> protection
#   protection      NOUN       dobj       --> had
#   against         ADP        prep       --> protection
#   double          ADJ        amod       --> spending
#   -               PUNCT      punct      --> spending
#   spending        NOUN       pobj       --> against
#   ,               PUNCT      punct      --> had
#   while           SCONJ      mark       --> were
#   b               NOUN       nsubj      --> were
#   -               PUNCT      punct      --> were
#   money           NOUN       nsubj      --> were
#   and             CCONJ      cc         --> money
#   bit             NOUN       compound   --> gold
#   gold            NOUN       conj       --> money
#   were            AUX        advcl      --> had
#   not             PART       neg        --> were
#   resistant       ADJ        acomp      --> were
#   to              ADP        prep       --> resistant
#   Sybil           PROPN      compound   --> attacks.[12
#   attacks.[12     PROPN      pobj       --> to
#   ]               X          punct      --> attacks.[12
#
#
#               SPACE      dep        --> ]
#   2008–2009       NUM        nummod     --> attacks.[12
#   :               PUNCT      punct      --> had
#   Creation        NOUN       compound   --> page
#
#                SPACE      dep        --> Creation
#   External        ADJ        amod       --> page
#   image           NOUN       compound   --> image
#
#                SPACE      dep        --> image
#   image           NOUN       compound   --> icon
#   icon            NOUN       compound   --> page
#   Cover           PROPN      compound   --> page
#   page            NOUN       dobj       --> had
#   of              ADP        prep       --> page
#   The             DET        det        --> Times
#   Times           PROPN      pobj       --> of
#   3               NUM        nummod     --> Times
#   January         PROPN      npadvmod   --> page
#   2009            NUM        nummod     --> January
#   showing         VERB       acl        --> page
#   the             DET        det        --> headline
#   headline        NOUN       dobj       --> showing
#   used            VERB       acl        --> headline
#   in              ADP        prep       --> used
#   the             DET        det        --> logos
#   genesis         NOUN       compound   --> block
#   block           NOUN       compound   --> logos
#
#
#
#              SPACE      dep        --> block
#   Bitcoin         PROPN      compound   --> logos
#   logos           NOUN       pobj       --> in
#   made            VERB       acl        --> logos
#   by              ADP        agent      --> made
#   Satoshi         PROPN      compound   --> Nakamoto
#   Nakamoto        PROPN      pobj       --> by
#   in              ADP        prep       --> made
#   2009            NUM        pobj       --> in
#   (               PUNCT      punct      --> left
#   left            ADV        parataxis  --> page
#   )               PUNCT      punct      --> left
#   and             CCONJ      cc         --> page
#   2010            NUM        conj       --> page
#   (               PUNCT      punct      --> right
#   right           INTJ       parataxis  --> 2010
#   )               PUNCT      punct      --> right
#   .               PUNCT      punct      --> had
#
#                SPACE      dep        --> .
#
# Sentence: The domain name bitcoin.org was registered on 18 August 2008.[16]
#   The             DET        det        --> name
#   domain          NOUN       compound   --> name
#   name            NOUN       nsubjpass  --> registered
#   bitcoin.org     X          appos      --> name
#   was             AUX        auxpass    --> registered
#   registered      VERB       ROOT       --> registered
#   on              ADP        prep       --> registered
#   18              NUM        nummod     --> 2008.[16
#   August          PROPN      compound   --> 2008.[16
#   2008.[16        NUM        pobj       --> on
#   ]               PUNCT      punct      --> registered
#
# Sentence: On 31 October 2008, a link to a white paper authored by Satoshi Nakamoto titled Bitcoin: A Peer-to-Peer Electronic Cash System was posted to a cryptography mailing list.[17] Nakamoto's identity remains unknown.[4]
#   On              ADP        prep       --> posted
#   31              NUM        nummod     --> October
#   October         PROPN      pobj       --> On
#   2008            NUM        nummod     --> October
#   ,               PUNCT      punct      --> posted
#   a               DET        det        --> link
#   link            NOUN       nsubjpass  --> posted
#   to              ADP        prep       --> link
#   a               DET        det        --> paper
#   white           ADJ        amod       --> paper
#   paper           NOUN       pobj       --> to
#   authored        VERB       acl        --> paper
#   by              ADP        agent      --> authored
#   Satoshi         PROPN      compound   --> Nakamoto
#   Nakamoto        PROPN      pobj       --> by
#   titled          VERB       acl        --> paper
#   Bitcoin         PROPN      oprd       --> titled
#   :               PUNCT      punct      --> link
#   A               DET        det        --> System
#   Peer            NOUN       nmod       --> System
#   -               PUNCT      punct      --> Peer
#   to              ADP        prep       --> Peer
#   -               PUNCT      punct      --> to
#   Peer            PROPN      pobj       --> to
#   Electronic      PROPN      compound   --> System
#   Cash            PROPN      compound   --> System
#   System          PROPN      nsubjpass  --> posted
#   was             AUX        auxpass    --> posted
#   posted          VERB       ROOT       --> posted
#   to              ADP        prep       --> posted
#   a               DET        det        --> list.[17
#   cryptography    NOUN       compound   --> mailing
#   mailing         NOUN       nmod       --> list.[17
#   list.[17        VERB       pobj       --> to
#   ]               PUNCT      punct      --> list.[17
#   Nakamoto        PROPN      poss       --> identity
#   's              PART       case       --> Nakamoto
#   identity        NOUN       nsubj      --> remains
#   remains         VERB       ccomp      --> posted
#   unknown.[4      ADJ        acomp      --> remains
#   ]               PUNCT      punct      --> remains
#
# Sentence: According to computer scientist Arvind Narayanan, all individual components of bitcoin originated in earlier academic literature.[12] Nakamoto's innovation was their complex interplay resulting in the first decentralized, Sybil resistant, Byzantine fault tolerant digital cash system, that would eventually be referred to as the first blockchain.[12][18] Nakamoto's paper was not peer reviewed and was initially ignored by academics, who argued that it could not work.[12]
#
# Nakamoto released bitcoin as open-source software.[19] On 3 January 2009, the bitcoin network was created when Nakamoto mined the starting block of the chain, known as the genesis block.[20] Embedded in this block was the text "The Times 03/Jan/2009 Chancellor on brink of second bailout for banks", which is the date and headline of an issue of The Times newspaper.[5]
#   According       VERB       prep       --> originated
#   to              ADP        prep       --> According
#   computer        NOUN       compound   --> scientist
#   scientist       NOUN       compound   --> Narayanan
#   Arvind          PROPN      compound   --> Narayanan
#   Narayanan       PROPN      pobj       --> to
#   ,               PUNCT      punct      --> originated
#   all             DET        det        --> components
#   individual      ADJ        amod       --> components
#   components      NOUN       nsubj      --> originated
#   of              ADP        prep       --> components
#   bitcoin         NOUN       pobj       --> of
#   originated      VERB       ccomp      --> referred
#   in              ADP        prep       --> originated
#   earlier         ADJ        amod       --> literature.[12
#   academic        ADJ        amod       --> literature.[12
#   literature.[12  NOUN       pobj       --> in
#   ]               PUNCT      punct      --> literature.[12
#   Nakamoto        PROPN      poss       --> innovation
#   's              PART       case       --> Nakamoto
#   innovation      NOUN       nsubj      --> was
#   was             AUX        conj       --> originated
#   their           PRON       poss       --> interplay
#   complex         ADJ        amod       --> interplay
#   interplay       NOUN       attr       --> was
#   resulting       VERB       acl        --> interplay
#   in              ADP        prep       --> resulting
#   the             DET        det        --> system
#   first           ADJ        amod       --> decentralized
#   decentralized   VERB       amod       --> system
#   ,               PUNCT      punct      --> system
#   Sybil           PROPN      nsubj      --> resistant
#   resistant       ADJ        amod       --> system
#   ,               PUNCT      punct      --> fault
#   Byzantine       ADJ        amod       --> fault
#   fault           VERB       nmod       --> system
#   tolerant        ADJ        amod       --> system
#   digital         ADJ        amod       --> system
#   cash            NOUN       compound   --> system
#   system          NOUN       pobj       --> in
#   ,               PUNCT      punct      --> referred
#   that            PRON       nsubjpass  --> referred
#   would           AUX        aux        --> referred
#   eventually      ADV        advmod     --> referred
#   be              AUX        auxpass    --> referred
#   referred        VERB       ROOT       --> referred
#   to              ADP        prep       --> referred
#   as              SCONJ      mark       --> reviewed
#   the             DET        det        --> blockchain.[12][18
#   first           ADJ        amod       --> blockchain.[12][18
#   blockchain.[12][18 PROPN      pobj       --> as
#   ]               PUNCT      punct      --> blockchain.[12][18
#   Nakamoto        PROPN      poss       --> paper
#   's              PART       case       --> Nakamoto
#   paper           NOUN       nsubj      --> was
#   was             AUX        auxpass    --> reviewed
#   not             PART       neg        --> was
#   peer            NOUN       acomp      --> was
#   reviewed        VERB       advcl      --> referred
#   and             CCONJ      cc         --> referred
#   was             AUX        auxpass    --> ignored
#   initially       ADV        advmod     --> ignored
#   ignored         VERB       conj       --> referred
#   by              ADP        agent      --> ignored
#   academics       NOUN       pobj       --> by
#   ,               PUNCT      punct      --> academics
#   who             PRON       nsubj      --> argued
#   argued          VERB       relcl      --> academics
#   that            SCONJ      mark       --> released
#   it              PRON       nsubj      --> released
#   could           AUX        aux        --> released
#   not             PART       neg        --> work.[12
#   work.[12        VERB       nmod       --> Nakamoto
#   ]               PUNCT      punct      --> work.[12
#
#
#               SPACE      dep        --> ]
#   Nakamoto        PROPN      nsubj      --> released
#   released        VERB       ccomp      --> argued
#   bitcoin         NOUN       dobj       --> released
#   as              ADP        prep       --> released
#   open            ADJ        amod       --> source
#   -               PUNCT      punct      --> source
#   source          NOUN       compound   --> software.[19
#   software.[19    NOUN       pobj       --> as
#   ]               PUNCT      punct      --> ignored
#   On              ADP        prep       --> created
#   3               NUM        nummod     --> January
#   January         PROPN      pobj       --> On
#   2009            NUM        nummod     --> January
#   ,               PUNCT      punct      --> created
#   the             DET        det        --> network
#   bitcoin         NOUN       compound   --> network
#   network         NOUN       nsubjpass  --> created
#   was             AUX        auxpass    --> created
#   created         VERB       advcl      --> referred
#   when            SCONJ      advmod     --> mined
#   Nakamoto        PROPN      nsubj      --> mined
#   mined           VERB       advcl      --> created
#   the             DET        det        --> block
#   starting        NOUN       compound   --> block
#   block           NOUN       dobj       --> mined
#   of              ADP        prep       --> block
#   the             DET        det        --> chain
#   chain           NOUN       pobj       --> of
#   ,               PUNCT      punct      --> block
#   known           VERB       acl        --> block
#   as              ADP        prep       --> known
#   the             DET        det        --> block.[20
#   genesis         NOUN       amod       --> block.[20
#   block.[20       NOUN       pobj       --> as
#   ]               PUNCT      punct      --> block
#   Embedded        VERB       acl        --> block
#   in              ADP        prep       --> Embedded
#   this            DET        det        --> block
#   block           NOUN       pobj       --> in
#   was             AUX        conj       --> created
#   the             DET        det        --> text
#   text            NOUN       attr       --> was
#   "               PUNCT      punct      --> text
#   The             DET        det        --> Chancellor
#   Times           PROPN      nmod       --> Chancellor
#   03              NUM        nummod     --> Jan/2009
#   /               SYM        punct      --> Jan/2009
#   Jan/2009        PROPN      compound   --> Chancellor
#   Chancellor      PROPN      appos      --> text
#   on              ADP        prep       --> Chancellor
#   brink           NOUN       pobj       --> on
#   of              ADP        prep       --> brink
#   second          ADJ        amod       --> bailout
#   bailout         NOUN       pobj       --> of
#   for             ADP        prep       --> bailout
#   banks           NOUN       pobj       --> for
#   "               PUNCT      punct      --> bailout
#   ,               PUNCT      punct      --> Chancellor
#   which           PRON       nsubj      --> is
#   is              AUX        relcl      --> Chancellor
#   the             DET        det        --> date
#   date            NOUN       attr       --> is
#   and             CCONJ      cc         --> date
#   headline        NOUN       conj       --> date
#   of              ADP        prep       --> date
#   an              DET        det        --> issue
#   issue           NOUN       pobj       --> of
#   of              ADP        prep       --> issue
#   The             DET        det        --> newspaper.[5
#   Times           PROPN      compound   --> newspaper.[5
#   newspaper.[5    NOUN       pobj       --> of
#   ]               PUNCT      punct      --> created
#
# Sentence: Nine days later, Hal Finney received the first bitcoin transaction: ten bitcoins from Nakamoto.[21]
#   Nine            NUM        nummod     --> days
#   days            NOUN       npadvmod   --> later
#   later           ADV        advmod     --> received
#   ,               PUNCT      punct      --> received
#   Hal             PROPN      compound   --> Finney
#   Finney          PROPN      nsubj      --> received
#   received        VERB       ROOT       --> received
#   the             DET        det        --> transaction
#   first           ADJ        amod       --> transaction
#   bitcoin         NOUN       compound   --> transaction
#   transaction     NOUN       dobj       --> received
#   :               PUNCT      punct      --> received
#   ten             NUM        nummod     --> bitcoins
#   bitcoins        NOUN       appos      --> transaction
#   from            ADP        prep       --> bitcoins
#   Nakamoto.[21    PROPN      pobj       --> from
#   ]               PUNCT      punct      --> bitcoins
#
# Sentence: Wei Dai and Nick Szabo were also early supporters.[20] On May 22, 2010, the first known commercial transaction using bitcoin occurred when programmer Laszlo Hanyecz bought two Papa John's pizzas for ₿10,000, in what would later be celebrated as "Bitcoin Pizza Day".[22]
#   Wei             PROPN      compound   --> Dai
#   Dai             PROPN      nsubj      --> were
#   and             CCONJ      cc         --> Dai
#   Nick            PROPN      compound   --> Szabo
#   Szabo           PROPN      conj       --> Dai
#   were            AUX        ccomp      --> occurred
#   also            ADV        advmod     --> were
#   early           ADV        advmod     --> supporters.[20
#   supporters.[20  NOUN       attr       --> were
#   ]               PUNCT      punct      --> were
#   On              ADP        prep       --> occurred
#   May             PROPN      pobj       --> On
#   22              NUM        nummod     --> May
#   ,               PUNCT      punct      --> May
#   2010            NUM        nummod     --> May
#   ,               PUNCT      punct      --> occurred
#   the             DET        det        --> transaction
#   first           ADJ        amod       --> transaction
#   known           VERB       amod       --> transaction
#   commercial      ADJ        amod       --> transaction
#   transaction     NOUN       nsubj      --> occurred
#   using           VERB       acl        --> transaction
#   bitcoin         NOUN       dobj       --> using
#   occurred        VERB       ROOT       --> occurred
#   when            SCONJ      advmod     --> bought
#   programmer      NOUN       compound   --> Hanyecz
#   Laszlo          PROPN      compound   --> Hanyecz
#   Hanyecz         PROPN      nsubj      --> bought
#   bought          VERB       advcl      --> occurred
#   two             NUM        nummod     --> John
#   Papa            PROPN      compound   --> John
#   John            PROPN      poss       --> pizzas
#   's              PART       case       --> John
#   pizzas          NOUN       dobj       --> bought
#   for             ADP        prep       --> bought
#   ₿               PROPN      pobj       --> for
#   10,000          NUM        nummod     --> ₿
#   ,               PUNCT      punct      --> bought
#   in              ADP        prep       --> bought
#   what            PRON       nsubjpass  --> celebrated
#   would           AUX        aux        --> celebrated
#   later           ADV        advmod     --> celebrated
#   be              AUX        auxpass    --> celebrated
#   celebrated      VERB       pcomp      --> in
#   as              ADP        prep       --> celebrated
#   "               PUNCT      punct      --> Day".[22
#   Bitcoin         PROPN      compound   --> Pizza
#   Pizza           PROPN      compound   --> Day".[22
#   Day".[22        NOUN       pobj       --> as
#   ]               PUNCT      punct      --> Day".[22
#
# Sentence: Satoshi tasked Finnish developer and early Bitcoin contributor Martti Malmi (fi) with creating content for the bitcoin.org website.[23][24]
#
# 2010–2012: Early growth
# Blockchain analysts estimate that Nakamoto had mined about one million bitcoins[25] before disappearing in 2010 when he handed the network alert key and control of the code repository over to Gavin Andresen.
#   Satoshi         PROPN      nmod       --> developer
#   tasked          VERB       amod       --> developer
#   Finnish         ADJ        amod       --> developer
#   developer       NOUN       nsubj      --> estimate
#   and             CCONJ      cc         --> developer
#   early           ADJ        amod       --> Bitcoin
#   Bitcoin         PROPN      compound   --> contributor
#   contributor     NOUN       compound   --> Malmi
#   Martti          PROPN      compound   --> Malmi
#   Malmi           PROPN      conj       --> developer
#   (               PUNCT      punct      --> Malmi
#   fi              NOUN       appos      --> Malmi
#   )               PUNCT      punct      --> Malmi
#   with            ADP        prep       --> developer
#   creating        VERB       pcomp      --> with
#   content         NOUN       dobj       --> creating
#   for             ADP        prep       --> content
#   the             DET        det        --> 2010–2012
#   bitcoin.org     X          nmod       --> website.[23][24
#   website.[23][24 PROPN      nmod       --> 2010–2012
#   ]               PUNCT      punct      --> website.[23][24
#
#
#               SPACE      dep        --> ]
#   2010–2012       NUM        pobj       --> for
#   :               PUNCT      punct      --> developer
#   Early           ADJ        amod       --> growth
#   growth          NOUN       compound   --> analysts
#
#                SPACE      dep        --> growth
#   Blockchain      PROPN      compound   --> analysts
#   analysts        NOUN       nsubj      --> estimate
#   estimate        VERB       ROOT       --> estimate
#   that            SCONJ      mark       --> mined
#   Nakamoto        PROPN      nsubj      --> mined
#   had             AUX        aux        --> mined
#   mined           VERB       ccomp      --> estimate
#   about           ADV        advmod     --> million
#   one             NUM        compound   --> million
#   million         NUM        nummod     --> bitcoins[25
#   bitcoins[25     NOUN       dobj       --> mined
#   ]               PUNCT      punct      --> mined
#   before          ADP        prep       --> mined
#   disappearing    VERB       pcomp      --> before
#   in              ADP        prep       --> disappearing
#   2010            NUM        pobj       --> in
#   when            SCONJ      advmod     --> handed
#   he              PRON       nsubj      --> handed
#   handed          VERB       advcl      --> disappearing
#   the             DET        det        --> network
#   network         NOUN       dobj       --> handed
#   alert           NOUN       compound   --> key
#   key             NOUN       dobj       --> handed
#   and             CCONJ      cc         --> key
#   control         NOUN       conj       --> key
#   of              ADP        prep       --> key
#   the             DET        det        --> repository
#   code            NOUN       compound   --> repository
#   repository      NOUN       pobj       --> of
#   over            ADP        prt        --> handed
#   to              ADP        prep       --> handed
#   Gavin           PROPN      compound   --> Andresen
#   Andresen        PROPN      pobj       --> to
#   .               PUNCT      punct      --> estimate
#
# Sentence: Andresen later became lead developer at the Bitcoin Foundation,[26][27] an organization founded in September 2012 to promote bitcoin.[28]
#
# After early "proof-of-concept" transactions, the first major users of bitcoin were black markets, such as the dark web Silk Road.
#   Andresen        PROPN      nsubj      --> became
#   later           ADV        advmod     --> became
#   became          VERB       ccomp      --> were
#   lead            ADJ        amod       --> developer
#   developer       NOUN       attr       --> became
#   at              ADP        prep       --> became
#   the             DET        det        --> Foundation,[26][27
#   Bitcoin         PROPN      compound   --> Foundation,[26][27
#   Foundation,[26][27 PROPN      pobj       --> at
#   ]               PUNCT      punct      --> Foundation,[26][27
#   an              DET        det        --> organization
#   organization    NOUN       appos      --> Foundation,[26][27
#   founded         VERB       acl        --> organization
#   in              ADP        prep       --> founded
#   September       PROPN      pobj       --> in
#   2012            NUM        nummod     --> September
#   to              PART       aux        --> promote
#   promote         VERB       advcl      --> founded
#   bitcoin.[28     PROPN      dobj       --> promote
#   ]               PUNCT      punct      --> organization
#
#
#               SPACE      dep        --> ]
#   After           ADP        prep       --> organization
#   early           ADJ        amod       --> transactions
#   "               PUNCT      punct      --> proof
#   proof           NOUN       nmod       --> transactions
#   -               PUNCT      punct      --> proof
#   of              ADP        prep       --> proof
#   -               PUNCT      punct      --> of
#   concept         NOUN       pobj       --> of
#   "               PUNCT      punct      --> transactions
#   transactions    NOUN       pobj       --> After
#   ,               PUNCT      punct      --> were
#   the             DET        det        --> users
#   first           ADJ        amod       --> users
#   major           ADJ        amod       --> users
#   users           NOUN       nsubj      --> were
#   of              ADP        prep       --> users
#   bitcoin         NOUN       pobj       --> of
#   were            AUX        ROOT       --> were
#   black           ADJ        amod       --> markets
#   markets         NOUN       attr       --> were
#   ,               PUNCT      punct      --> markets
#   such            ADJ        amod       --> as
# ...
#   spend           VERB       acl        --> requirements
#   the             DET        det        --> funds
#   funds           NOUN       dobj       --> spend
#   .               PUNCT      punct      --> encode
#
# Sentence: One common example is "multisig", in which multiple distinct private keys must mutually sign any transaction that attempts to spend the funds.[6]: ch. 7
#
# Bitcoin transactions use a Forth-like scripting language,[6]: ch. 5  involving one or more inputs and outputs.
#   One             NUM        nummod     --> example
#   common          ADJ        amod       --> example
#   example         NOUN       nsubj      --> is
#   is              AUX        ROOT       --> is
#   "               PUNCT      punct      --> is
#   multisig        PROPN      attr       --> is
#   "               PUNCT      punct      --> multisig
#   ,               PUNCT      punct      --> multisig
#   in              ADP        prep       --> sign
#   which           PRON       pobj       --> in
#   multiple        ADJ        amod       --> keys
#   distinct        ADJ        amod       --> keys
#   private         ADJ        amod       --> keys
#   keys            NOUN       nsubj      --> sign
#   must            AUX        aux        --> sign
#   mutually        ADV        advmod     --> sign
#   sign            VERB       relcl      --> multisig
#   any             DET        det        --> transaction
#   transaction     NOUN       dobj       --> sign
#   that            PRON       nsubj      --> attempts
#   attempts        VERB       relcl      --> transaction
#   to              PART       aux        --> spend
#   spend           VERB       xcomp      --> attempts
#   the             DET        det        --> funds.[6
#   funds.[6        NOUN       dobj       --> spend
#   ]               PUNCT      punct      --> is
#   :               PUNCT      punct      --> is
#                   SPACE      dep        --> :
#   ch              NOUN       attr       --> is
#   .               PROPN      attr       --> is
#   7               NUM        nummod     --> transactions
#
#
#              SPACE      dep        --> 7
#   Bitcoin         PROPN      compound   --> transactions
#   transactions    NOUN       nsubj      --> use
#   use             VERB       ccomp      --> is
#   a               DET        det        --> scripting
#   Forth           ADV        npadvmod   --> like
#   -               PUNCT      punct      --> like
#   like            ADJ        amod       --> scripting
#   scripting       VERB       dobj       --> use
#   language,[6     NOUN       dobj       --> scripting
#   ]               PUNCT      punct      --> use
#   :               PUNCT      punct      --> use
#                   SPACE      dep        --> :
#   ch              NOUN       punct      --> is
#   .               PROPN      attr       --> is
#   5               NUM        nummod     --> .
#                   SPACE      dep        --> 5
#   involving       VERB       advcl      --> is
#   one             NUM        nummod     --> inputs
#   or              CCONJ      cc         --> one
#   more            ADJ        conj       --> one
#   inputs          NOUN       dobj       --> involving
#   and             CCONJ      cc         --> inputs
#   outputs         NOUN       conj       --> inputs
#   .               PUNCT      punct      --> is
#
# Sentence: When sending bitcoins, a user specifies the recipients' addresses and the amount for each output.
#   When            SCONJ      advmod     --> sending
#   sending         VERB       advcl      --> specifies
#   bitcoins        NOUN       dobj       --> sending
#   ,               PUNCT      punct      --> specifies
#   a               DET        det        --> user
#   user            NOUN       nsubj      --> specifies
#   specifies       VERB       ROOT       --> specifies
#   the             DET        det        --> recipients
#   recipients      NOUN       poss       --> addresses
#   '               PART       case       --> recipients
#   addresses       NOUN       dobj       --> specifies
#   and             CCONJ      cc         --> addresses
#   the             DET        det        --> amount
#   amount          NOUN       conj       --> addresses
#   for             ADP        prep       --> amount
#   each            DET        det        --> output
#   output          NOUN       pobj       --> for
#   .               PUNCT      punct      --> specifies
#
# Sentence: This allows sending bitcoins to several recipients in a single transaction.
#   This            PRON       nsubj      --> allows
#   allows          VERB       ROOT       --> allows
#   sending         VERB       xcomp      --> allows
#   bitcoins        NOUN       dobj       --> sending
#   to              ADP        dative     --> sending
#   several         ADJ        amod       --> recipients
#   recipients      NOUN       pobj       --> to
#   in              ADP        prep       --> sending
#   a               DET        det        --> transaction
#   single          ADJ        amod       --> transaction
#   transaction     NOUN       pobj       --> in
#   .               PUNCT      punct      --> allows
#
# Sentence: To prevent double-spending, each input must refer to a previous unspent output in the blockchain.[80] Using multiple inputs is similar to using multiple coins in a cash transaction.
#   To              PART       aux        --> prevent
#   prevent         VERB       advcl      --> refer
#   double          ADJ        amod       --> spending
#   -               PUNCT      punct      --> spending
#   spending        NOUN       dobj       --> prevent
#   ,               PUNCT      punct      --> refer
#   each            DET        det        --> input
#   input           NOUN       nsubj      --> refer
#   must            AUX        aux        --> refer
#   refer           VERB       ccomp      --> is
#   to              ADP        prep       --> refer
#   a               DET        det        --> output
#   previous        ADJ        amod       --> output
#   unspent         ADJ        amod       --> output
#   output          NOUN       pobj       --> to
#   in              ADP        prep       --> output
#   the             DET        det        --> blockchain.[80
#   blockchain.[80  PROPN      pobj       --> in
#   ]               PUNCT      punct      --> refer
#   Using           VERB       csubj      --> is
#   multiple        ADJ        amod       --> inputs
#   inputs          NOUN       dobj       --> Using
#   is              AUX        ROOT       --> is
#   similar         ADJ        acomp      --> is
#   to              ADP        prep       --> similar
#   using           VERB       pcomp      --> to
#   multiple        ADJ        amod       --> coins
#   coins           NOUN       dobj       --> using
#   in              ADP        prep       --> using
#   a               DET        det        --> transaction
#   cash            NOUN       compound   --> transaction
#   transaction     NOUN       pobj       --> in
#   .               PUNCT      punct      --> is
#
# Sentence: As in a cash transaction, the sum of inputs can exceed the intended sum of payments.
#   As              ADP        prep       --> exceed
#   in              ADP        prep       --> As
#   a               DET        det        --> transaction
#   cash            NOUN       compound   --> transaction
#   transaction     NOUN       pobj       --> in
#   ,               PUNCT      punct      --> exceed
#   the             DET        det        --> sum
#   sum             NOUN       nsubj      --> exceed
#   of              ADP        prep       --> sum
#   inputs          NOUN       pobj       --> of
#   can             AUX        aux        --> exceed
#   exceed          VERB       ROOT       --> exceed
#   the             DET        det        --> sum
#   intended        ADJ        amod       --> sum
#   sum             NOUN       dobj       --> exceed
#   of              ADP        prep       --> sum
#   payments        NOUN       pobj       --> of
#   .               PUNCT      punct      --> exceed
#
# Sentence: In such a case, an additional output can return the change back to the payer.[80] Unallocated input satoshis in the transaction become the transaction fee.[80]
#
# Losing a private key means losing access to the bitcoins, with no other proof of ownership accepted by the protocol.[29] For instance, in 2013, a user lost ₿7,500, valued at US$7.5 million, by accidentally discarding a hard drive with the private key.[81]
#   In              ADP        prep       --> return
#   such            DET        predet     --> case
#   a               DET        det        --> case
#   case            NOUN       pobj       --> In
#   ,               PUNCT      punct      --> return
#   an              DET        det        --> output
#   additional      ADJ        amod       --> output
#   output          NOUN       nsubj      --> return
#   can             AUX        aux        --> return
#   return          VERB       ccomp      --> become
#   the             DET        det        --> change
#   change          NOUN       dobj       --> return
#   back            ADV        advmod     --> return
#   to              ADP        prep       --> back
#   the             DET        det        --> payer.[80
#   payer.[80       PROPN      pobj       --> to
#   ]               PUNCT      punct      --> return
#   Unallocated     ADJ        amod       --> input
#   input           NOUN       compound   --> satoshis
#   satoshis        NOUN       nsubj      --> become
#   in              ADP        prep       --> satoshis
#   the             DET        det        --> transaction
#   transaction     NOUN       pobj       --> in
#   become          VERB       ccomp      --> lost
#   the             DET        det        --> transaction
#   transaction     NOUN       attr       --> become
#   fee.[80         NUM        nummod     --> transaction
#   ]               PUNCT      punct      --> become
#
#
#               SPACE      dep        --> ]
#   Losing          VERB       advcl      --> become
#   a               DET        det        --> means
#   private         ADJ        amod       --> means
#   key             NOUN       amod       --> means
#   means           NOUN       dobj       --> Losing
#   losing          VERB       acl        --> means
#   access          NOUN       dobj       --> losing
#   to              ADP        prep       --> access
#   the             DET        det        --> bitcoins
#   bitcoins        NOUN       pobj       --> to
#   ,               PUNCT      punct      --> Losing
#   with            ADP        prep       --> Losing
#   no              DET        det        --> proof
#   other           ADJ        amod       --> proof
#   proof           NOUN       pobj       --> with
#   of              ADP        prep       --> proof
#   ownership       NOUN       pobj       --> of
#   accepted        VERB       acl        --> ownership
#   by              ADP        agent      --> accepted
#   the             DET        det        --> protocol.[29
#   protocol.[29    NOUN       pobj       --> by
#   ]               X          dobj       --> Losing
#   For             ADP        prep       --> Losing
#   instance        NOUN       pobj       --> For
#   ,               PUNCT      punct      --> Losing
#   in              ADP        prep       --> Losing
#   2013            NUM        pobj       --> in
#   ,               PUNCT      punct      --> lost
#   a               DET        det        --> user
#   user            NOUN       nsubj      --> lost
#   lost            VERB       ROOT       --> lost
#   ₿               PROPN      dobj       --> lost
#   7,500           NUM        nummod     --> ₿
#   ,               PUNCT      punct      --> ₿
#   valued          VERB       advcl      --> lost
#   at              ADP        prep       --> valued
#   US$             SYM        quantmod   --> million
#   7.5             NUM        compound   --> million
#   million         NUM        pobj       --> at
#   ,               PUNCT      punct      --> valued
#   by              ADP        prep       --> valued
#   accidentally    ADV        advmod     --> discarding
#   discarding      VERB       pcomp      --> by
#   a               DET        det        --> drive
#   hard            ADJ        amod       --> drive
#   drive           NOUN       dobj       --> discarding
#   with            ADP        prep       --> drive
#   the             DET        det        --> key.[81
#   private         ADJ        amod       --> key.[81
#   key.[81         NOUN       pobj       --> with
#   ]               X          punct      --> lost
#
# Sentence: It is estimated that around 20% of all bitcoins are lost.[82] The private key must also be kept secret as its exposure, such as through a data breach, can lead to theft of the associated bitcoins.[6]: ch.
#   It              PRON       nsubjpass  --> estimated
#   is              AUX        auxpass    --> estimated
#   estimated       VERB       ROOT       --> estimated
#   that            SCONJ      mark       --> are
#   around          ADP        advmod     --> 20
#   20              NUM        nummod     --> %
#   %               NOUN       nsubj      --> are
#   of              ADP        prep       --> %
#   all             DET        det        --> bitcoins
#   bitcoins        NOUN       pobj       --> of
#   are             AUX        ccomp      --> estimated
#   lost.[82        ADJ        acomp      --> are
#   ]               X          punct      --> are
#   The             DET        det        --> key
#   private         ADJ        amod       --> key
#   key             NOUN       nsubjpass  --> kept
#   must            AUX        aux        --> kept
#   also            ADV        advmod     --> kept
#   be              AUX        auxpass    --> kept
#   kept            VERB       conj       --> estimated
#   secret          ADJ        oprd       --> kept
#   as              ADP        prep       --> secret
#   its             PRON       poss       --> exposure
#   exposure        NOUN       pobj       --> as
#   ,               PUNCT      punct      --> exposure
#   such            ADJ        amod       --> as
#   as              ADP        prep       --> exposure
#   through         ADP        prep       --> as
#   a               DET        det        --> breach
#   data            NOUN       compound   --> breach
#   breach          NOUN       pobj       --> through
#   ,               PUNCT      punct      --> exposure
#   can             AUX        aux        --> lead
#   lead            VERB       ccomp      --> estimated
#   to              ADP        prep       --> lead
#   theft           NOUN       pobj       --> to
#   of              ADP        prep       --> theft
#   the             DET        det        --> bitcoins.[6
#   associated      ADJ        amod       --> bitcoins.[6
#   bitcoins.[6     NOUN       pobj       --> of
#   ]               PUNCT      punct      --> lead
#   :               PUNCT      punct      --> ch
#                   SPACE      dep        --> :
#   ch              NOUN       npadvmod   --> estimated
#   .               PROPN      punct      --> estimated
#
# Sentence: 10 [83] As of December 2017, approximately ₿980,000 had been stolen from cryptocurrency exchanges.[84]
#
#   10              NUM        nummod     --> [
#                   SPACE      dep        --> 10
#   [               X          dep        --> stolen
#   83              NUM        punct      --> [
#   ]               PUNCT      dep        --> As
#   As              ADP        prep       --> stolen
#   of              ADP        prep       --> As
#   December        PROPN      pobj       --> of
#   2017            NUM        nummod     --> December
#   ,               PUNCT      punct      --> stolen
#   approximately   ADV        advmod     --> stolen
#   ₿               PROPN      nsubjpass  --> stolen
#   980,000         NUM        nsubjpass  --> stolen
#   had             AUX        aux        --> stolen
#   been            AUX        auxpass    --> stolen
#   stolen          VERB       ROOT       --> stolen
#   from            ADP        prep       --> stolen
#   cryptocurrency  PROPN      compound   --> exchanges.[84
#   exchanges.[84   PROPN      pobj       --> from
#   ]               X          pobj       --> from
#
#                SPACE      dep        --> ]

# %% [markdown]
# #Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9412a776b3ba4e0ea4318ebe551a9220-0" class="displacy" width="397300" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Bitcoin (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">abbreviation:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">BTC;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">sign:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">₿)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">decentralized</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">cryptocurrency.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Based</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">free-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">market</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">ideology,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">bitcoin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">invented</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">2008</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">when</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">unknown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">entity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">published</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">white</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">paper</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">under</tspan>
#     <tspan class="displacy-tag" dy="2
